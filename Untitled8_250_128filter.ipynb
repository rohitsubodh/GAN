# %% [markdown]
# <a href="https://colab.research.google.com/github/rohitsubodh/GAN/blob/main/Untitled8_250_128filter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import keras
import numpy as np
from keras import models
from keras import layers
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score
from sklearn.datasets import make_classification
from matplotlib import pyplot
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import preprocessing
from keras.models import Sequential,Model
from keras.layers import Dense, Dropout,Input, Conv1D, MaxPooling1D, UpSampling1D, concatenate, BatchNormalization, Activation, add
from keras.layers import Embedding,LeakyReLU
from keras.layers import Conv1D, GlobalAveragePooling1D, MaxPooling1D, Flatten, LocallyConnected1D, BatchNormalization
import scipy.signal
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.decomposition import PCA, KernelPCA

# %%
data = pd.read_excel('/content/PPG_new.xlsx',sheet_name='0-1')
target = pd.read_excel('/content/PPG_new.xlsx',sheet_name='target 0-1')

# %%
# data1=data
# kpca=KernelPCA(kernel="rbf",fit_inverse_transform=True, gamma=10)
# data=kpca.fit_transform(data)

# %%
# data1=data
# kpca=KernelPCA(kernel="rbf",fit_inverse_transform=True, gamma=10)
# data=kpca.fit_transform(data)
# data.shape

# %%
# x= data[0,:]
x=data.iloc[0,:]
plt.plot(x)
plt.show
data1=data

# %%
# from sklearn.preprocessing import StandardScaler,MinMaxScaler

# data = StandardScaler().fit_transform(data)
# data=MinMaxScaler().fit_transform(data)

# %%
# Applying median filter
data=scipy.signal.medfilt(data)
data
x= data[0,:]
plt.plot(x)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
# Design of low pass chebyshev filter
sos= scipy.signal.cheby2(4, 10, 25, 'low', fs=1000, output='sos')
sos
# Out:
# array([[ 0.26741176, -0.49141861,  0.26741176,  1.        , -1.6346899 ,
#          0.69069827],
#        [ 1.        , -1.97118242,  1.        ,  1.        , -1.92658177,
#          0.94891457]])

# %%
data= scipy.signal.sosfilt(sos, data) # applying chebyshev filter
x= data[0,:]
plt.plot(x)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
# Applying backward forward filter
b, a = scipy.signal.butter(8, 0.125) # filter design

data = scipy.signal.filtfilt(b, a, data, method="gust")

x= data[0,:]
plt.plot(x)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
data1=data
kpca=KernelPCA(kernel="rbf",fit_inverse_transform=True, gamma=10)
data=kpca.fit_transform(data)
data.shape
# Out:
# (495, 494)

# %%
data=data1
kpca=KernelPCA(kernel="rbf",fit_inverse_transform=True, gamma=10)
data=kpca.fit_transform(data)
data.shape
# Out:
# (495, 494)

# %%
x= data[0,:]
plt.plot(x)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
# from sklearn.preprocessing import StandardScaler

# data = StandardScaler().fit_transform(data)

# xTrain1 = scaler.transform(xTrain1)

# xTest1 = scaler.transform(xTest1)

# %%
from sklearn.model_selection import train_test_split
xTrain1, xTest1, yTrain1, yTest1 = train_test_split(data, target, test_size = 0.3, random_state = 42)

# %%
# from sklearn.preprocessing import StandardScaler

# scaler = StandardScaler().fit(xTrain1)

# xTrain1 = scaler.transform(xTrain1)

# xTest1 = scaler.transform(xTest1)

# %%
xTrain11 = np.expand_dims(xTrain1, axis=2)
yTrain11 = tf.keras.utils.to_categorical(yTrain1, num_classes=2)
xTest11 =  np.expand_dims(xTest1, axis=2)
yTest11 = tf.keras.utils.to_categorical(yTest1, num_classes=2)

# %%
# input_shape = (2100, 1)
input_shape = (494, 1)

# %%
  #   x = 32
  # #  from keras
  #   inputs = Input(input_shape)
  #   conv1 = Conv1D(x,3, activation='relu', padding='same')(inputs)
  #   conv1 = BatchNormalization()(conv1)
  #   conv1 = Conv1D(x,3, activation='relu', padding='same')(conv1)
  #   conv1 = BatchNormalization()(conv1)
  #   pool1 = MaxPooling1D(pool_size=2)(conv1)

  #   conv2 = Conv1D(x*2,3, activation='relu', padding='same')(pool1)
  #   conv2 = BatchNormalization()(conv2)
  #   conv2 = Conv1D(x*2,3, activation='relu', padding='same')(conv2)
  #   conv2 = BatchNormalization()(conv2)
  #   pool2 = MaxPooling1D(pool_size=2)(conv2)

  #   conv3 = Conv1D(x*4,3, activation='relu', padding='same')(pool2)
  #   conv3 = BatchNormalization()(conv3)
  #   conv3 = Conv1D(x*4,3, activation='relu', padding='same')(conv3)
  #   conv3 = BatchNormalization()(conv3)
  #   pool3 = MaxPooling1D(pool_size=2)(conv3)

  #   conv4 = Conv1D(x*8,3, activation='relu', padding='same')(pool3)
  #   conv4 = BatchNormalization()(conv4)
  #   conv4 = Conv1D(x*8,3, activation='relu', padding='same')(conv4)
  #   conv4 = BatchNormalization()(conv4)
  #   pool4 = MaxPooling1D(pool_size=2)(conv4)

  #   conv5 = Conv1D(x*16, 3, activation='relu', padding='same')(pool4)
  #   conv5 = BatchNormalization()(conv5)
  #   conv5 = Conv1D(x*16, 3, activation='relu', padding='same')(conv5)
  #   conv5 = BatchNormalization()(conv5)

  #   up6 = concatenate([UpSampling1D(size=2)(conv5), conv4], axis=2)
  #   conv6 = Conv1D(x*8, 3, activation='relu', padding='same')(up6)
  #   conv6 = BatchNormalization()(conv6)
  #   conv6 = Conv1D(x*8, 3, activation='relu', padding='same')(conv6)
  #   conv6 = BatchNormalization()(conv6)
    
  #   up7 = concatenate([UpSampling1D(size=2)(conv6), conv3], axis=2)
  #   conv7 = Conv1D(x*4, 3, activation='relu', padding='same')(up7)
  #   conv7 = BatchNormalization()(conv7)
  #   conv7 = Conv1D(x*4, 3, activation='relu', padding='same')(conv7)
  #   conv7 = BatchNormalization()(conv7)

  #   up8 = concatenate([UpSampling1D(size=2)(conv7), conv2], axis=2)
  #   conv8 = Conv1D(x*2, 3, activation='relu', padding='same')(up8)
  #   conv8 = BatchNormalization()(conv8)
  #   conv8 = Conv1D(x*2, 3, activation='relu', padding='same')(conv8)
  #   conv8 = BatchNormalization()(conv8)

  #   up9 = concatenate([UpSampling1D(size=2)(conv8), conv1], axis=2)
  #   conv9 = Conv1D(x, 3, activation='relu', padding='same')(up9)
  #   conv9 = BatchNormalization()(conv9)
  #   conv9 = Conv1D(x, 3, activation='relu', padding='same')(conv9)
  #   conv9 = BatchNormalization()(conv9)

  #   conv10 = Conv1D(1, 1)(conv9)

  #   model = Model(inputs=[inputs], outputs=[conv10])
  #   # model.compile(loss='mean_absolute_error',optimizer='adam',metrics=['mean_squared_error'], loss_weights=[1., 0.9, 0.8, 0.7, 0.6])                                                         
  #   model.compile(loss='categorical_crossentropy',
  #                   optimizer='adam',
  #                   metrics=['accuracy'])

  #   # checkpoint1_ = ModelCheckpoint(os.path.join('models','{}_model1_fold{}.h5'.format(mdlName1,foldname)), verbose=1, monitor='val_out_loss',save_best_only=True, mode='auto')  
  #                                                                       # train approximation network for 100 epochs
  #   # history1 = mdl1.fit(X_train,{'out': Y_train['out'], 'level1': Y_train['level1'], 'level2':Y_train['level2'], 'level3':Y_train['level3'] , 'level4':Y_train['level4']},epochs=100,batch_size=256,validation_data=(X_val,{'out': Y_val['out'], 'level1': Y_val['level1'], 'level2':Y_val['level2'], 'level3':Y_val['level3'] , 'level4':Y_val['level4']}),callbacks=[checkpoint1_],verbose=1)
  #   history = model.fit(xTrain1, yTrain1, validation_split=0.3, epochs=200, batch_size=20, verbose=2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-2f2cc658a060> in <module>()
#      31 conv5 = BatchNormalization()(conv5)
#      32
# ---> 33 up6 = concatenate([UpSampling1D(size=2)(conv5), conv4], axis=2)
#      34 conv6 = Conv1D(x*8, 3, activation='relu', padding='same')(up6)
#      35 conv6 = BatchNormalization()(conv6)
#
# /usr/local/lib/python3.7/dist-packages/keras/layers/merge.py in concatenate(inputs, axis, **kwargs)
#     942       A tensor, the concatenation of the inputs alongside axis `axis`.
#     943   """
# --> 944   return Concatenate(axis=axis, **kwargs)(inputs)
#     945
#     946
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#     975     if _in_functional_construction_mode(self, inputs, args, kwargs, input_list):
#     976       return self._functional_construction_call(inputs, args, kwargs,
# --> 977                                                 input_list)
#     978
#     979     # Maintains info about the `Layer.call` stack.
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py in _functional_construction_call(self, inputs, args, kwargs, input_list)
#    1113       # Check input assumptions set after layer building, e.g. input shape.
#    1114       outputs = self._keras_tensor_symbolic_call(
# -> 1115           inputs, input_masks, args, kwargs)
#    1116
#    1117       if outputs is None:
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py in _keras_tensor_symbolic_call(self, inputs, input_masks, args, kwargs)
#     846       return tf.nest.map_structure(keras_tensor.KerasTensor, output_signature)
#     847     else:
# --> 848       return self._infer_output_signature(inputs, args, kwargs, input_masks)
#     849
#     850   def _infer_output_signature(self, inputs, args, kwargs, input_masks):
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py in _infer_output_signature(self, inputs, args, kwargs, input_masks)
#     884           # overridden).
#     885           # TODO(kaftan): do we maybe_build here, or have we already done it?
# --> 886           self._maybe_build(inputs)
#     887           inputs = self._maybe_cast_inputs(inputs)
#     888           outputs = call_fn(inputs, *args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py in _maybe_build(self, inputs)
#    2657         # operations.
#    2658         with tf_utils.maybe_init_scope(self):
# -> 2659           self.build(input_shapes)  # pylint:disable=not-callable
#    2660       # We must set also ensure that the layer is marked as built, and the build
#    2661       # shape is stored since user defined build functions may not be calling
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/tf_utils.py in wrapper(instance, input_shape)
#     257     if input_shape is not None:
#     258       input_shape = convert_shapes(input_shape, to_tuples=True)
# --> 259     output_shape = fn(instance, input_shape)
#     260     # Return shapes from `fn` as TensorShapes.
#     261     if output_shape is not None:
#
# /usr/local/lib/python3.7/dist-packages/keras/layers/merge.py in build(self, input_shape)
#     513             shape[axis] for shape in shape_set if shape[axis] is not None)
#     514         if len(unique_dims) > 1:
# --> 515           raise ValueError(err_msg)
#     516
#     517   def _merge_function(self, inputs):
#
# ValueError: A `Concatenate` layer requires inputs with matching shapes except for the concat axis. Got inputs shapes: [(None, 60, 512), (None, 61, 256)]

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-b7fd50d38e9f> in <module>()
# ----> 1 Conv1D()
#
# TypeError: __init__() missing 2 required positional arguments: 'filters' and 'kernel_size'

# %%
#CNN Model

model = Sequential()
model.add(Conv1D(32, 3, activation='relu', input_shape=input_shape[0:]))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.1))
model.add(Conv1D(64, 3, activation='relu', name="my_intermediate_layer"))
model.add(MaxPooling1D(3))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.1))
model.add(Conv1D(128, 3, activation='relu'))
model.add(BatchNormalization())
# model.add(LeakyReLU(alpha=0.1))
# model.add(Conv1D(256, 3, activation='relu'))
model.add(GlobalAveragePooling1D())
model.add(Dropout(0.5))
model.add(Dense(100, name="dense"))
model.add(Dense(2, activation='softmax', name="dense1"))
model.compile(loss='categorical_crossentropy',
                    optimizer='adam',
                    metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_29 (Conv1D)           (None, 492, 32)           128
# _________________________________________________________________
# batch_normalization_29 (Batc (None, 492, 32)           128
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 492, 32)           0
# _________________________________________________________________
# my_intermediate_layer (Conv1 (None, 490, 64)           6208
# _________________________________________________________________
# max_pooling1d_11 (MaxPooling (None, 163, 64)           0
# _________________________________________________________________
# batch_normalization_30 (Batc (None, 163, 64)           256
# _________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)   (None, 163, 64)           0
# _________________________________________________________________
# conv1d_30 (Conv1D)           (None, 161, 128)          24704
# _________________________________________________________________
# batch_normalization_31 (Batc (None, 161, 128)          512
# _________________________________________________________________
# global_average_pooling1d_3 ( (None, 128)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 100)               12900
# _________________________________________________________________
# dense1 (Dense)               (None, 2)                 202
# =================================================================
# Total params: 45,038
# Trainable params: 44,590
# Non-trainable params: 448
# _________________________________________________________________

# %%
# from sklearn.model_selection import train_test_split
# xTrain1, xTest1, yTrain1, yTest1 = train_test_split(data, target, test_size = 0.3, random_state = 42)

# xTrain1.shape, yTest1.shape

# xTrain11 = np.expand_dims(xTrain1, axis=2)
# yTrain11 = tf.keras.utils.to_categorical(yTrain1, num_classes=2)
# xTest11 =  np.expand_dims(xTest1, axis=2)
# yTest11 = tf.keras.utils.to_categorical(yTest1, num_classes=2)

# input_shape = (2100, 1)

# model = Sequential()

# model.add(Dense(128, activation='relu', input_shape=(2100, ) ))
# #model.add(Dropout(0.2))
# model.add(BatchNormalization())

# model.add(Dense(64, activation='relu', kernel_regularizer='l2', kernel_initializer='he_uniform'))
# model.add(BatchNormalization())
# model.add(Dropout(0.5))
# model.add(Dense(32, activation='relu', kernel_regularizer='l2', kernel_initializer='he_uniform'))
# model.add(BatchNormalization())
# model.add(Dropout(0.1))
# model.add(Dense(16, activation='relu', kernel_regularizer='l2', kernel_initializer='he_uniform'))
# model.add(BatchNormalization())
# model.add(Dropout(0.1))
# #model.add(Dense(16, activation='relu', kernel_regularizer='l2'))
# #model.add(Dropout(0.05))
# #model.add(Dense(64, activation='relu'))#

# model.add(Dense(1, activation='sigmoid')) 
# opt = tf.keras.optimizers.Adam(learning_rate=.005)
# model.compile(loss='binary_crossentropy',
#               optimizer= opt,
#                metrics=['accuracy'])
# model.summary()               
# history = model.fit(xTrain1, yTrain1, validation_split=0.3, epochs=200, batch_size=20, verbose=2)

# # model.evaluate(x=xTest1, y=yTest1, verbose=2)

# # import os
# # import seaborn as sns
# # #plot the training and validation accuracy and loss at each epoch
# # loss = history.history['loss']
# # val_loss = history.history['val_loss']
# # epochs = range(1, len(loss) + 1)
# # plt.plot(loss[10:], 'b', label='Training loss')
# # plt.plot(val_loss[10:], 'g', label='Validation loss')
# # plt.title('Training and validation loss')
# # plt.xlabel('Epochs')
# # plt.ylabel('Loss')
# # plt.legend()
# # plt.show()

# # acc = history.history['accuracy']
# # val_acc = history.history['val_accuracy']
# # plt.plot(epochs, acc, 'r', label='Training acc')
# # plt.plot(epochs, val_acc, 'c', label='Validation acc')
# # plt.title('Training and validation accuracy')
# # plt.xlabel('Epochs')
# # plt.ylabel('Accuracy')
# # plt.legend()
# # plt.show()

# %%
from keras.callbacks import EarlyStopping
#set early stopping monitor so the model stops training when it won't improve anymore
early_stopping_monitor = EarlyStopping(patience=500)

#train model
history=model.fit(xTrain11, yTrain11, validation_data = (xTest11, yTest11), epochs=250, batch_size=16)
# Out:
# Epoch 1/250
# 22/22 [==============================] - 2s 24ms/step - loss: 0.6202 - accuracy: 0.6647 - val_loss: 0.7044 - val_accuracy: 0.4899
# Epoch 2/250
# 22/22 [==============================] - 0s 11ms/step - loss: 0.6011 - accuracy: 0.6792 - val_loss: 0.7425 - val_accuracy: 0.4899
# Epoch 3/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.5665 - accuracy: 0.6965 - val_loss: 0.8083 - val_accuracy: 0.4899
# Epoch 4/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.5724 - accuracy: 0.7081 - val_loss: 0.9424 - val_accuracy: 0.4899
# Epoch 5/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.5670 - accuracy: 0.7139 - val_loss: 0.8990 - val_accuracy: 0.4899
# Epoch 6/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.5490 - accuracy: 0.7312 - val_loss: 0.9872 - val_accuracy: 0.4899
# Epoch 7/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.5466 - accuracy: 0.7312 - val_loss: 0.9318 - val_accuracy: 0.4899
# Epoch 8/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.5395 - accuracy: 0.7370 - val_loss: 0.8332 - val_accuracy: 0.4899
# Epoch 9/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.5117 - accuracy: 0.7428 - val_loss: 0.7884 - val_accuracy: 0.4899
# Epoch 10/250
# 22/22 [==============================] - 0s 14ms/step - loss: 0.5200 - accuracy: 0.7428 - val_loss: 0.8437 - val_accuracy: 0.4899
# Epoch 11/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.4951 - accuracy: 0.7746 - val_loss: 1.1694 - val_accuracy: 0.4899
# Epoch 12/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.5090 - accuracy: 0.7514 - val_loss: 1.4873 - val_accuracy: 0.4899
# Epoch 13/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.5053 - accuracy: 0.7370 - val_loss: 1.2438 - val_accuracy: 0.4899
# Epoch 14/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.5299 - accuracy: 0.7399 - val_loss: 1.5816 - val_accuracy: 0.4899
# Epoch 15/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.
250
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0559 - accuracy: 0.9827 - val_loss: 1.8313 - val_accuracy: 0.5906
# Epoch 111/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0400 - accuracy: 0.9827 - val_loss: 0.9304 - val_accuracy: 0.7517
# Epoch 112/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0885 - accuracy: 0.9711 - val_loss: 1.3350 - val_accuracy: 0.6913
# Epoch 113/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.1200 - accuracy: 0.9509 - val_loss: 2.6350 - val_accuracy: 0.6913
# Epoch 114/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0343 - accuracy: 0.9942 - val_loss: 4.7649 - val_accuracy: 0.6376
# Epoch 115/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.1093 - accuracy: 0.9653 - val_loss: 3.4929 - val_accuracy: 0.6174
# Epoch 116/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.1113 - accuracy: 0.9509 - val_loss: 8.3258 - val_accuracy: 0.5168
# Epoch 117/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0772 - accuracy: 0.9740 - val_loss: 4.7536 - val_accuracy: 0.6174
# Epoch 118/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0525 - accuracy: 0.9798 - val_loss: 2.7065 - val_accuracy: 0.6644
# Epoch 119/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0483 - accuracy: 0.9855 - val_loss: 3.5465 - val_accuracy: 0.6174
# Epoch 120/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0398 - accuracy: 0.9855 - val_loss: 2.5329 - val_accuracy: 0.6913
# Epoch 121/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0483 - accuracy: 0.9798 - val_loss: 2.0089 - val_accuracy: 0.6980
# Epoch 122/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0332 - accuracy: 0.9827 - val_loss: 4.0130 - val_accuracy: 0.6644
# Epoch 123/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0704 - accuracy: 0.9769 - val_loss: 2.6838 - val_accuracy: 0.7181
# Epoch 124/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0574 - accuracy: 0.9798 - val_loss: 2.8864 - val_accuracy: 0.6443
# Epoch 125/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0678 - accuracy: 0.9769 - val_loss: 3.1549 - val_accuracy: 0.5638
# Epoch 126/250
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0342 - accuracy: 0.9884 - val_loss: 2.2949 - val_accuracy: 0.6107
# Epoch 127/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0459 - accuracy: 0.9798 - val_loss: 8.8067 - val_accuracy: 0.4966
# Epoch 128/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0182 - accuracy: 0.9913 - val_loss: 7.3967 - val_accuracy: 0.4899
# Epoch 129/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0427 - accuracy: 0.9827 - val_loss: 7.2268 - val_accuracy: 0.4899
# Epoch 130/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0507 - accuracy: 0.9827 - val_loss: 5.0324 - val_accuracy: 0.4899
# Epoch 131/250
# 22/22 [==============================] - 0s 14ms/step - loss: 0.1676 - accuracy: 0.9422 - val_loss: 1.4220 - val_accuracy: 0.6980
# Epoch 132/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.1096 - accuracy: 0.9566 - val_loss: 2.9877 - val_accuracy: 0.6711
# Epoch 133/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0874 - accuracy: 0.9653 - val_loss: 15.5534 - val_accuracy: 0.5168
# Epoch 134/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0689 - accuracy: 0.9682 - val_loss: 9.4250 - val_accuracy: 0.5839
# Epoch 135/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0848 - accuracy: 0.9682 - val_loss: 8.2512 - val_accuracy: 0.5772
# Epoch 136/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0242 - accuracy: 0.9942 - val_loss: 5.7200 - val_accuracy: 0.5906
# Epoch 137/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0267 - accuracy: 0.9913 - val_loss: 4.1255 - val_accuracy: 0.6443
# Epoch 138/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0464 - accuracy: 0.9827 - val_loss: 3.1017 - val_accuracy: 0.6577
# Epoch 139/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0192 - accuracy: 0.9913 - val_loss: 2.5255 - val_accuracy: 0.6174
# Epoch 140/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0381 - accuracy: 0.9855 - val_loss: 3.1175 - val_accuracy: 0.5436
# Epoch 141/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0282 - accuracy: 0.9913 - val_loss: 2.0623 - val_accuracy: 0.6779
# Epoch 142/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0178 - accuracy: 0.9942 - val_loss: 1.5246 - val_accuracy: 0.7181
# Epoch 143/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0210 - accuracy: 0.9942 - val_loss: 1.5618 - val_accuracy: 0.7047
# Epoch 144/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0607 - accuracy: 0.9711 - val_loss: 1.0499 - val_accuracy: 0.7718
# Epoch 145/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0303 - accuracy: 0.9884 - val_loss: 2.6733 - val_accuracy: 0.6443
# Epoch 146/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0277 - accuracy: 0.9913 - val_loss: 3.7872 - val_accuracy: 0.6443
# Epoch 147/250
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0404 - accuracy: 0.9884 - val_loss: 1.3611 - val_accuracy: 0.7248
# Epoch 148/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0397 - accuracy: 0.9855 - val_loss: 1.9385 - val_accuracy: 0.6779
# Epoch 149/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0286 - accuracy: 0.9827 - val_loss: 2.3112 - val_accuracy: 0.6711
# Epoch 150/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0407 - accuracy: 0.9884 - val_loss: 2.5879 - val_accuracy: 0.6644
# Epoch 151/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0174 - accuracy: 0.9971 - val_loss: 3.0620 - val_accuracy: 0.6107
# Epoch 152/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0485 - accuracy: 0.9855 - val_loss: 3.0248 - val_accuracy: 0.5839
# Epoch 153/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0316 - accuracy: 0.9913 - val_loss: 4.3895 - val_accuracy: 0.6242
# Epoch 154/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0216 - accuracy: 0.9913 - val_loss: 2.7387 - val_accuracy: 0.7047
# Epoch 155/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0200 - accuracy: 0.9942 - val_loss: 1.5191 - val_accuracy: 0.6913
# Epoch 156/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.1266 - accuracy: 0.9624 - val_loss: 1.2645 - val_accuracy: 0.6913
# Epoch 157/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0801 - accuracy: 0.9682 - val_loss: 7.0773 - val_accuracy: 0.4899
# Epoch 158/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0782 - accuracy: 0.9798 - val_loss: 5.3249 - val_accuracy: 0.5168
# Epoch 159/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0554 - accuracy: 0.9798 - val_loss: 5.2793 - val_accuracy: 0.5839
# Epoch 160/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0546 - accuracy: 0.9711 - val_loss: 8.0534 - val_accuracy: 0.5705
# Epoch 161/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0286 - accuracy: 0.9884 - val_loss: 5.5047 - val_accuracy: 0.5839
# Epoch 162/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0493 - accuracy: 0.9798 - val_loss: 2.5603 - val_accuracy: 0.6644
# Epoch 163/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0279 - accuracy: 0.9913 - val_loss: 0.9759 - val_accuracy: 0.7450
# Epoch 164/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0649 - accuracy: 0.9769 - val_loss: 3.2856 - val_accuracy: 0.6309
# Epoch 165/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0499 - accuracy: 0.9827 - val_loss: 3.5236 - val_accuracy: 0.6711
# Epoch 166/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.1030 - accuracy: 0.9653 - val_loss: 7.3294 - val_accuracy: 0.5906
# Epoch 167/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.1098 - accuracy: 0.9624 - val_loss: 13.0576 - val_accuracy: 0.5369
# Epoch 168/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0483 - accuracy: 0.9884 - val_loss: 8.8090 - val_accuracy: 0.5503
# Epoch 169/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0381 - accuracy: 0.9855 - val_loss: 8.4011 - val_accuracy: 0.5638
# Epoch 170/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0827 - accuracy: 0.9769 - val_loss: 1.8941 - val_accuracy: 0.7181
# Epoch 171/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0568 - accuracy: 0.9827 - val_loss: 2.0900 - val_accuracy: 0.6644
# Epoch 172/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0450 - accuracy: 0.9827 - val_loss: 1.0036 - val_accuracy: 0.7315
# Epoch 173/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0644 - accuracy: 0.9740 - val_loss: 2.3429 - val_accuracy: 0.6376
# Epoch 174/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0448 - accuracy: 0.9884 - val_loss: 1.5884 - val_accuracy: 0.6846
# Epoch 175/250
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0467 - accuracy: 0.9884 - val_loss: 1.1381 - val_accuracy: 0.7651
# Epoch 176/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0120 - accuracy: 0.9971 - val_loss: 1.1860 - val_accuracy: 0.6913
# Epoch 177/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0196 - accuracy: 0.9942 - val_loss: 2.3091 - val_accuracy: 0.6577
# Epoch 178/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0287 - accuracy: 0.9884 - val_loss: 2.6518 - val_accuracy: 0.7315
# Epoch 179/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0459 - accuracy: 0.9798 - val_loss: 1.1761 - val_accuracy: 0.7248
# Epoch 180/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0345 - accuracy: 0.9855 - val_loss: 1.0036 - val_accuracy: 0.6913
# Epoch 181/250
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0109 - accuracy: 0.9971 - val_loss: 1.0035 - val_accuracy: 0.6577
# Epoch 182/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0938 - accuracy: 0.9740 - val_loss: 1.8089 - val_accuracy: 0.6577
# Epoch 183/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0476 - accuracy: 0.9769 - val_loss: 1.9474 - val_accuracy: 0.6846
# Epoch 184/250
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0291 - accuracy: 0.9884 - val_loss: 1.4702 - val_accuracy: 0.7047
# Epoch 185/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0743 - accuracy: 0.9798 - val_loss: 2.0531 - val_accuracy: 0.6846
# Epoch 186/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0424 - accuracy: 0.9827 - val_loss: 1.5348 - val_accuracy: 0.6980
# Epoch 187/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0164 - accuracy: 0.9942 - val_loss: 3.7409 - val_accuracy: 0.6577
# Epoch 188/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0137 - accuracy: 0.9942 - val_loss: 2.6771 - val_accuracy: 0.6443
# Epoch 189/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0224 - accuracy: 0.9913 - val_loss: 2.4626 - val_accuracy: 0.6309
# Epoch 190/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0455 - accuracy: 0.9827 - val_loss: 1.3843 - val_accuracy: 0.6913
# Epoch 191/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0378 - accuracy: 0.9798 - val_loss: 3.8449 - val_accuracy: 0.5570
# Epoch 192/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0280 - accuracy: 0.9884 - val_loss: 3.1948 - val_accuracy: 0.6510
# Epoch 193/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0147 - accuracy: 0.9971 - val_loss: 1.4581 - val_accuracy: 0.7517
# Epoch 194/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0234 - accuracy: 0.9942 - val_loss: 2.0655 - val_accuracy: 0.7450
# Epoch 195/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0618 - accuracy: 0.9740 - val_loss: 0.7699 - val_accuracy: 0.7517
# Epoch 196/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0285 - accuracy: 0.9827 - val_loss: 0.7206 - val_accuracy: 0.7785
# Epoch 197/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0590 - accuracy: 0.9798 - val_loss: 1.9961 - val_accuracy: 0.6711
# Epoch 198/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0331 - accuracy: 0.9855 - val_loss: 3.3579 - val_accuracy: 0.5906
# Epoch 199/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0630 - accuracy: 0.9798 - val_loss: 1.3409 - val_accuracy: 0.6913
# Epoch 200/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0461 - accuracy: 0.9798 - val_loss: 2.6134 - val_accuracy: 0.6846
# Epoch 201/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0587 - accuracy: 0.9711 - val_loss: 1.7922 - val_accuracy: 0.7114
# Epoch 202/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0425 - accuracy: 0.9827 - val_loss: 1.0132 - val_accuracy: 0.7315
# Epoch 203/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0287 - accuracy: 0.9855 - val_loss: 2.0175 - val_accuracy: 0.5906
# Epoch 204/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0618 - accuracy: 0.9769 - val_loss: 2.5426 - val_accuracy: 0.6309
# Epoch 205/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0605 - accuracy: 0.9769 - val_loss: 3.5604 - val_accuracy: 0.6980
# Epoch 206/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0426 - accuracy: 0.9855 - val_loss: 3.3627 - val_accuracy: 0.6510
# Epoch 207/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0327 - accuracy: 0.9971 - val_loss: 2.4594 - val_accuracy: 0.6242
# Epoch 208/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0277 - accuracy: 0.9913 - val_loss: 1.1469 - val_accuracy: 0.7450
# Epoch 209/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0257 - accuracy: 0.9884 - val_loss: 4.0731 - val_accuracy: 0.6376
# Epoch 210/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0490 - accuracy: 0.9827 - val_loss: 5.3052 - val_accuracy: 0.6510
# Epoch 211/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0510 - accuracy: 0.9798 - val_loss: 2.8761 - val_accuracy: 0.6779
# Epoch 212/250
# 22/22 [==============================] - 0s 11ms/step - loss: 0.0492 - accuracy: 0.9740 - val_loss: 7.3821 - val_accuracy: 0.5705
# Epoch 213/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0473 - accuracy: 0.9884 - val_loss: 11.4356 - val_accuracy: 0.5369
# Epoch 214/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0606 - accuracy: 0.9769 - val_loss: 5.1151 - val_accuracy: 0.6510
# Epoch 215/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0494 - accuracy: 0.9827 - val_loss: 3.7440 - val_accuracy: 0.6644
# Epoch 216/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0602 - accuracy: 0.9682 - val_loss: 2.4842 - val_accuracy: 0.6779
# Epoch 217/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0237 - accuracy: 0.9913 - val_loss: 1.3137 - val_accuracy: 0.7047
# Epoch 218/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0245 - accuracy: 0.9884 - val_loss: 2.2968 - val_accuracy: 0.6644
# Epoch 219/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0452 - accuracy: 0.9855 - val_loss: 1.9942 - val_accuracy: 0.7047
# Epoch 220/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0671 - accuracy: 0.9711 - val_loss: 1.6022 - val_accuracy: 0.7114
# Epoch 221/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0550 - accuracy: 0.9769 - val_loss: 4.4726 - val_accuracy: 0.5973
# Epoch 222/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0532 - accuracy: 0.9769 - val_loss: 5.7524 - val_accuracy: 0.5973
# Epoch 223/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0388 - accuracy: 0.9884 - val_loss: 2.5058 - val_accuracy: 0.6510
# Epoch 224/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0372 - accuracy: 0.9769 - val_loss: 3.0948 - val_accuracy: 0.6443
# Epoch 225/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0101 - accuracy: 0.9971 - val_loss: 3.3592 - val_accuracy: 0.6309
# Epoch 226/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0284 - accuracy: 0.9913 - val_loss: 3.4735 - val_accuracy: 0.5570
# Epoch 227/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0172 - accuracy: 0.9971 - val_loss: 2.2803 - val_accuracy: 0.6510
# Epoch 228/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0175 - accuracy: 0.9942 - val_loss: 2.1625 - val_accuracy: 0.6779
# Epoch 229/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0140 - accuracy: 0.9942 - val_loss: 3.5446 - val_accuracy: 0.6107
# Epoch 230/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0258 - accuracy: 0.9884 - val_loss: 1.7682 - val_accuracy: 0.7450
# Epoch 231/250
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0289 - accuracy: 0.9913 - val_loss: 0.9431 - val_accuracy: 0.7315
# Epoch 232/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0108 - accuracy: 1.0000 - val_loss: 1.4482 - val_accuracy: 0.7315
# Epoch 233/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0399 - accuracy: 0.9827 - val_loss: 2.4669 - val_accuracy: 0.6846
# Epoch 234/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0173 - accuracy: 0.9942 - val_loss: 2.1895 - val_accuracy: 0.6644
# Epoch 235/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0811 - accuracy: 0.9798 - val_loss: 1.6512 - val_accuracy: 0.6577
# Epoch 236/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0587 - accuracy: 0.9769 - val_loss: 2.2667 - val_accuracy: 0.6510
# Epoch 237/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0551 - accuracy: 0.9827 - val_loss: 5.8726 - val_accuracy: 0.5772
# Epoch 238/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0813 - accuracy: 0.9769 - val_loss: 9.3477 - val_accuracy: 0.6443
# Epoch 239/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0500 - accuracy: 0.9682 - val_loss: 6.7076 - val_accuracy: 0.6107
# Epoch 240/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0231 - accuracy: 0.9913 - val_loss: 4.2702 - val_accuracy: 0.6309
# Epoch 241/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0270 - accuracy: 0.9942 - val_loss: 4.1204 - val_accuracy: 0.6644
# Epoch 242/250
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0534 - accuracy: 0.9827 - val_loss: 1.9430 - val_accuracy: 0.6443
# Epoch 243/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0235 - accuracy: 0.9855 - val_loss: 2.8103 - val_accuracy: 0.6174
# Epoch 244/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0192 - accuracy: 0.9942 - val_loss: 3.5678 - val_accuracy: 0.6174
# Epoch 245/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0206 - accuracy: 0.9942 - val_loss: 1.5646 - val_accuracy: 0.7248
# Epoch 246/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0178 - accuracy: 0.9913 - val_loss: 3.2741 - val_accuracy: 0.6779
# Epoch 247/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0481 - accuracy: 0.9769 - val_loss: 3.4297 - val_accuracy: 0.6309
# Epoch 248/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0217 - accuracy: 0.9913 - val_loss: 2.5572 - val_accuracy: 0.6644
# Epoch 249/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 1.6557 - val_accuracy: 0.6779
# Epoch 250/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 1.6415 - val_accuracy: 0.7517

# %%
import os
import seaborn as sns
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
prediction_NN = model.predict(xTest11)
prediction_NN = np.argmax(prediction_NN, axis=-1)
#Print overall accuracy
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(yTest1, prediction_NN))
#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(yTest1, prediction_NN)
print(cm)
sns.heatmap(cm, annot=True)
# Out:
# Accuracy =  0.7516778523489933
# [[47 26]
#  [11 65]]
