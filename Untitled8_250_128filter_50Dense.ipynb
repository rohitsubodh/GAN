# %% [markdown]
# <a href="https://colab.research.google.com/github/rohitsubodh/GAN/blob/main/Untitled8_250_128filter_50Dense.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import keras
import numpy as np
from keras import models
from keras import layers
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score
from sklearn.datasets import make_classification
from matplotlib import pyplot
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import preprocessing
from keras.models import Sequential,Model
from keras.layers import Dense, Dropout,Input, Conv1D, MaxPooling1D, UpSampling1D, concatenate, BatchNormalization, Activation, add
from keras.layers import Embedding,LeakyReLU
from keras.layers import Conv1D, GlobalAveragePooling1D, MaxPooling1D, Flatten, LocallyConnected1D, BatchNormalization
import scipy.signal
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.decomposition import PCA, KernelPCA

# %%
data = pd.read_excel('/content/PPG_new.xlsx',sheet_name='0-1')
target = pd.read_excel('/content/PPG_new.xlsx',sheet_name='target 0-1')

# %%
# data1=data
# kpca=KernelPCA(kernel="rbf",fit_inverse_transform=True, gamma=10)
# data=kpca.fit_transform(data)

# %%
# data1=data
# kpca=KernelPCA(kernel="rbf",fit_inverse_transform=True, gamma=10)
# data=kpca.fit_transform(data)
# data.shape

# %%
# x= data[0,:]
x=data.iloc[0,:]
plt.plot(x)
plt.show
data1=data

# %%
# from sklearn.preprocessing import StandardScaler,MinMaxScaler

# data = StandardScaler().fit_transform(data)
# data=MinMaxScaler().fit_transform(data)

# %%
# Applying median filter
data=scipy.signal.medfilt(data)
data
x= data[0,:]
plt.plot(x)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
# Design of low pass chebyshev filter
sos= scipy.signal.cheby2(4, 10, 25, 'low', fs=1000, output='sos')
sos
# Out:
# array([[ 0.26741176, -0.49141861,  0.26741176,  1.        , -1.6346899 ,
#          0.69069827],
#        [ 1.        , -1.97118242,  1.        ,  1.        , -1.92658177,
#          0.94891457]])

# %%
data= scipy.signal.sosfilt(sos, data) # applying chebyshev filter
x= data[0,:]
plt.plot(x)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
# Applying backward forward filter
b, a = scipy.signal.butter(8, 0.125) # filter design

data = scipy.signal.filtfilt(b, a, data, method="gust")

x= data[0,:]
plt.plot(x)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
data1=data
kpca=KernelPCA(kernel="rbf",fit_inverse_transform=True, gamma=10)
data=kpca.fit_transform(data)
data.shape
# Out:
# (495, 494)

# %%
data=data1
kpca=KernelPCA(kernel="rbf",fit_inverse_transform=True, gamma=10)
data=kpca.fit_transform(data)
data.shape
# Out:
# (495, 494)

# %%
x= data[0,:]
plt.plot(x)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
# from sklearn.preprocessing import StandardScaler

# data = StandardScaler().fit_transform(data)

# xTrain1 = scaler.transform(xTrain1)

# xTest1 = scaler.transform(xTest1)

# %%
from sklearn.model_selection import train_test_split
xTrain1, xTest1, yTrain1, yTest1 = train_test_split(data, target, test_size = 0.3, random_state = 42)

# %%
# from sklearn.preprocessing import StandardScaler

# scaler = StandardScaler().fit(xTrain1)

# xTrain1 = scaler.transform(xTrain1)

# xTest1 = scaler.transform(xTest1)

# %%
xTrain11 = np.expand_dims(xTrain1, axis=2)
yTrain11 = tf.keras.utils.to_categorical(yTrain1, num_classes=2)
xTest11 =  np.expand_dims(xTest1, axis=2)
yTest11 = tf.keras.utils.to_categorical(yTest1, num_classes=2)

# %%
# input_shape = (2100, 1)
input_shape = (494, 1)

# %%
  #   x = 32
  # #  from keras
  #   inputs = Input(input_shape)
  #   conv1 = Conv1D(x,3, activation='relu', padding='same')(inputs)
  #   conv1 = BatchNormalization()(conv1)
  #   conv1 = Conv1D(x,3, activation='relu', padding='same')(conv1)
  #   conv1 = BatchNormalization()(conv1)
  #   pool1 = MaxPooling1D(pool_size=2)(conv1)

  #   conv2 = Conv1D(x*2,3, activation='relu', padding='same')(pool1)
  #   conv2 = BatchNormalization()(conv2)
  #   conv2 = Conv1D(x*2,3, activation='relu', padding='same')(conv2)
  #   conv2 = BatchNormalization()(conv2)
  #   pool2 = MaxPooling1D(pool_size=2)(conv2)

  #   conv3 = Conv1D(x*4,3, activation='relu', padding='same')(pool2)
  #   conv3 = BatchNormalization()(conv3)
  #   conv3 = Conv1D(x*4,3, activation='relu', padding='same')(conv3)
  #   conv3 = BatchNormalization()(conv3)
  #   pool3 = MaxPooling1D(pool_size=2)(conv3)

  #   conv4 = Conv1D(x*8,3, activation='relu', padding='same')(pool3)
  #   conv4 = BatchNormalization()(conv4)
  #   conv4 = Conv1D(x*8,3, activation='relu', padding='same')(conv4)
  #   conv4 = BatchNormalization()(conv4)
  #   pool4 = MaxPooling1D(pool_size=2)(conv4)

  #   conv5 = Conv1D(x*16, 3, activation='relu', padding='same')(pool4)
  #   conv5 = BatchNormalization()(conv5)
  #   conv5 = Conv1D(x*16, 3, activation='relu', padding='same')(conv5)
  #   conv5 = BatchNormalization()(conv5)

  #   up6 = concatenate([UpSampling1D(size=2)(conv5), conv4], axis=2)
  #   conv6 = Conv1D(x*8, 3, activation='relu', padding='same')(up6)
  #   conv6 = BatchNormalization()(conv6)
  #   conv6 = Conv1D(x*8, 3, activation='relu', padding='same')(conv6)
  #   conv6 = BatchNormalization()(conv6)
    
  #   up7 = concatenate([UpSampling1D(size=2)(conv6), conv3], axis=2)
  #   conv7 = Conv1D(x*4, 3, activation='relu', padding='same')(up7)
  #   conv7 = BatchNormalization()(conv7)
  #   conv7 = Conv1D(x*4, 3, activation='relu', padding='same')(conv7)
  #   conv7 = BatchNormalization()(conv7)

  #   up8 = concatenate([UpSampling1D(size=2)(conv7), conv2], axis=2)
  #   conv8 = Conv1D(x*2, 3, activation='relu', padding='same')(up8)
  #   conv8 = BatchNormalization()(conv8)
  #   conv8 = Conv1D(x*2, 3, activation='relu', padding='same')(conv8)
  #   conv8 = BatchNormalization()(conv8)

  #   up9 = concatenate([UpSampling1D(size=2)(conv8), conv1], axis=2)
  #   conv9 = Conv1D(x, 3, activation='relu', padding='same')(up9)
  #   conv9 = BatchNormalization()(conv9)
  #   conv9 = Conv1D(x, 3, activation='relu', padding='same')(conv9)
  #   conv9 = BatchNormalization()(conv9)

  #   conv10 = Conv1D(1, 1)(conv9)

  #   model = Model(inputs=[inputs], outputs=[conv10])
  #   # model.compile(loss='mean_absolute_error',optimizer='adam',metrics=['mean_squared_error'], loss_weights=[1., 0.9, 0.8, 0.7, 0.6])                                                         
  #   model.compile(loss='categorical_crossentropy',
  #                   optimizer='adam',
  #                   metrics=['accuracy'])

  #   # checkpoint1_ = ModelCheckpoint(os.path.join('models','{}_model1_fold{}.h5'.format(mdlName1,foldname)), verbose=1, monitor='val_out_loss',save_best_only=True, mode='auto')  
  #                                                                       # train approximation network for 100 epochs
  #   # history1 = mdl1.fit(X_train,{'out': Y_train['out'], 'level1': Y_train['level1'], 'level2':Y_train['level2'], 'level3':Y_train['level3'] , 'level4':Y_train['level4']},epochs=100,batch_size=256,validation_data=(X_val,{'out': Y_val['out'], 'level1': Y_val['level1'], 'level2':Y_val['level2'], 'level3':Y_val['level3'] , 'level4':Y_val['level4']}),callbacks=[checkpoint1_],verbose=1)
  #   history = model.fit(xTrain1, yTrain1, validation_split=0.3, epochs=200, batch_size=20, verbose=2)

# %%
#CNN Model

model = Sequential()
model.add(Conv1D(32, 3, activation='relu', input_shape=input_shape[0:]))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.1))
model.add(Conv1D(64, 3, activation='relu', name="my_intermediate_layer"))
model.add(MaxPooling1D(3))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.1))
model.add(Conv1D(128, 3, activation='relu'))
model.add(BatchNormalization())
# model.add(LeakyReLU(alpha=0.1))
# model.add(Conv1D(256, 3, activation='relu'))
model.add(GlobalAveragePooling1D())
model.add(Dropout(0.5))
model.add(Dense(50, name="dense"))
model.add(Dense(2, activation='softmax', name="dense1"))
model.compile(loss='categorical_crossentropy',
                    optimizer='adam',
                    metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_31 (Conv1D)           (None, 492, 32)           128
# _________________________________________________________________
# batch_normalization_32 (Batc (None, 492, 32)           128
# _________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)   (None, 492, 32)           0
# _________________________________________________________________
# my_intermediate_layer (Conv1 (None, 490, 64)           6208
# _________________________________________________________________
# max_pooling1d_12 (MaxPooling (None, 163, 64)           0
# _________________________________________________________________
# batch_normalization_33 (Batc (None, 163, 64)           256
# _________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)   (None, 163, 64)           0
# _________________________________________________________________
# conv1d_32 (Conv1D)           (None, 161, 128)          24704
# _________________________________________________________________
# batch_normalization_34 (Batc (None, 161, 128)          512
# _________________________________________________________________
# global_average_pooling1d_4 ( (None, 128)               0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 50)                6450
# _________________________________________________________________
# dense1 (Dense)               (None, 2)                 102
# =================================================================
# Total params: 38,488
# Trainable params: 38,040
# Non-trainable params: 448
# _________________________________________________________________

# %%
# from sklearn.model_selection import train_test_split
# xTrain1, xTest1, yTrain1, yTest1 = train_test_split(data, target, test_size = 0.3, random_state = 42)

# xTrain1.shape, yTest1.shape

# xTrain11 = np.expand_dims(xTrain1, axis=2)
# yTrain11 = tf.keras.utils.to_categorical(yTrain1, num_classes=2)
# xTest11 =  np.expand_dims(xTest1, axis=2)
# yTest11 = tf.keras.utils.to_categorical(yTest1, num_classes=2)

# input_shape = (2100, 1)

# model = Sequential()

# model.add(Dense(128, activation='relu', input_shape=(2100, ) ))
# #model.add(Dropout(0.2))
# model.add(BatchNormalization())

# model.add(Dense(64, activation='relu', kernel_regularizer='l2', kernel_initializer='he_uniform'))
# model.add(BatchNormalization())
# model.add(Dropout(0.5))
# model.add(Dense(32, activation='relu', kernel_regularizer='l2', kernel_initializer='he_uniform'))
# model.add(BatchNormalization())
# model.add(Dropout(0.1))
# model.add(Dense(16, activation='relu', kernel_regularizer='l2', kernel_initializer='he_uniform'))
# model.add(BatchNormalization())
# model.add(Dropout(0.1))
# #model.add(Dense(16, activation='relu', kernel_regularizer='l2'))
# #model.add(Dropout(0.05))
# #model.add(Dense(64, activation='relu'))#

# model.add(Dense(1, activation='sigmoid')) 
# opt = tf.keras.optimizers.Adam(learning_rate=.005)
# model.compile(loss='binary_crossentropy',
#               optimizer= opt,
#                metrics=['accuracy'])
# model.summary()               
# history = model.fit(xTrain1, yTrain1, validation_split=0.3, epochs=200, batch_size=20, verbose=2)

# # model.evaluate(x=xTest1, y=yTest1, verbose=2)

# # import os
# # import seaborn as sns
# # #plot the training and validation accuracy and loss at each epoch
# # loss = history.history['loss']
# # val_loss = history.history['val_loss']
# # epochs = range(1, len(loss) + 1)
# # plt.plot(loss[10:], 'b', label='Training loss')
# # plt.plot(val_loss[10:], 'g', label='Validation loss')
# # plt.title('Training and validation loss')
# # plt.xlabel('Epochs')
# # plt.ylabel('Loss')
# # plt.legend()
# # plt.show()

# # acc = history.history['accuracy']
# # val_acc = history.history['val_accuracy']
# # plt.plot(epochs, acc, 'r', label='Training acc')
# # plt.plot(epochs, val_acc, 'c', label='Validation acc')
# # plt.title('Training and validation accuracy')
# # plt.xlabel('Epochs')
# # plt.ylabel('Accuracy')
# # plt.legend()
# # plt.show()

# %%
from keras.callbacks import EarlyStopping
#set early stopping monitor so the model stops training when it won't improve anymore
early_stopping_monitor = EarlyStopping(patience=500)

#train model
history=model.fit(xTrain11, yTrain11, validation_data = (xTest11, yTest11), epochs=250, batch_size=16)
# Out:
# Epoch 1/250
# 22/22 [==============================] - 2s 25ms/step - loss: 0.6204 - accuracy: 0.6821 - val_loss: 0.6966 - val_accuracy: 0.4899
# Epoch 2/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.5725 - accuracy: 0.7254 - val_loss: 0.7314 - val_accuracy: 0.4899
# Epoch 3/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.5622 - accuracy: 0.7052 - val_loss: 0.8049 - val_accuracy: 0.4899
# Epoch 4/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.5681 - accuracy: 0.7052 - val_loss: 0.8687 - val_accuracy: 0.4899
# Epoch 5/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.5280 - accuracy: 0.7312 - val_loss: 0.8959 - val_accuracy: 0.4899
# Epoch 6/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.5355 - accuracy: 0.7370 - val_loss: 0.9136 - val_accuracy: 0.4899
# Epoch 7/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.5244 - accuracy: 0.7543 - val_loss: 0.9490 - val_accuracy: 0.4899
# Epoch 8/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.5228 - accuracy: 0.7688 - val_loss: 0.9374 - val_accuracy: 0.4899
# Epoch 9/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.4867 - accuracy: 0.7630 - val_loss: 0.9737 - val_accuracy: 0.4899
# Epoch 10/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.4533 - accuracy: 0.7775 - val_loss: 0.9744 - val_accuracy: 0.4899
# Epoch 11/250
# 22/22 [==============================] - 0s 14ms/step - loss: 0.4514 - accuracy: 0.8035 - val_loss: 1.0913 - val_accuracy: 0.4899
# Epoch 12/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.4298 - accuracy: 0.7919 - val_loss: 0.9241 - val_accuracy: 0.4899
# Epoch 13/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.4177 - accuracy: 0.8237 - val_loss: 1.1426 - val_accuracy: 0.4899
# Epoch 14/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.4117 - accuracy: 0.8208 - val_loss: 1.0713 - val_accuracy: 0.4899
# Epoch 15/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.3867 - accuracy: 0.8295 - val_loss: 1.1772 - val_accuracy: 0.4899
# Epoch 16/250
# 22/22 [==============================] - 0s 11ms/step - loss: 0.3449 - accuracy: 0.8526 - val_loss: 1.1603 - val_accuracy: 0.4899
# Epoch 17/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.3812 - accuracy: 0.8353 - val_loss: 1.7123 - val_accuracy: 0.4899
# Epoch 18/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3462 - accuracy: 0.8671 - val_loss: 1.3167 - val_accuracy: 0.4899
# Epoch 19/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3071 - accuracy: 0.8931 - val_loss: 1.6882 - val_accuracy: 0.4899
# Epoch 20/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.2669 - accuracy: 0.9046 - val_loss: 1.8633 - val_accuracy: 0.4899
# Epoch 21/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.2782 - accuracy: 0.8873 - val_loss: 1.6763 - val_accuracy: 0.4899
# Epoch 22/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.2905 - accuracy: 0.8699 - val_loss: 1.3858 - val_accuracy: 0.4899
# Epoch 23/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.2635 - accuracy: 0.8902 - val_loss: 1.1670 - val_accuracy: 0.4899
# Epoch 24/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.2685 - accuracy: 0.8902 - val_loss: 1.8960 - val_accuracy: 0.4899
# Epoch 25/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.2522 - accuracy: 0.9017 - val_loss: 1.1952 - val_accuracy: 0.5168
# Epoch 26/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3041 - accuracy: 0.8699 - val_loss: 0.8040 - val_accuracy: 0.5772
# Epoch 27/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.2901 - accuracy: 0.8728 - val_loss: 1.2757 - val_accuracy: 0.5101
# Epoch 28/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.2614 - accuracy: 0.8786 - val_loss: 1.4640 - val_accuracy: 0.5638
# Epoch 29/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.2577 - accuracy: 0.8988 - val_loss: 2.1274 - val_accuracy: 0.4899
# Epoch 30/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.2234 - accuracy: 0.9017 - val_loss: 1.6003 - val_accuracy: 0.5503
# Epoch 31/250
# 22/22 [==============================] - 0s 11ms/step - loss: 0.1597 - accuracy: 0.9509 - val_loss: 0.9111 - val_accuracy: 0.6711
# Epoch 32/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.1711 - accuracy: 0.9422 - val_loss: 0.7629 - val_accuracy: 0.7181
# Epoch 33/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.1729 - accuracy: 0.9451 - val_loss: 0.9391 - val_accuracy: 0.6309
# Epoch 34/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.1463 - accuracy: 0.9480 - val_loss: 1.2038 - val_accuracy: 0.6711
# Epoch 35/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.1614 - accuracy: 0.9306 - val_loss: 0.5890 - val_accuracy: 0.7047
# Epoch 36/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.1066 - accuracy: 0.9682 - val_loss: 1.4182 - val_accuracy: 0.6309
# Epoch 37/250
# 22/22 [==============================] - 0s 14ms/step - loss: 0.1566 - accuracy: 0.9422 - val_loss: 2.4350 - val_accuracy: 0.5369
# Epoch 38/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.1384 - accuracy: 0.9422 - val_loss: 1.5080 - val_accuracy: 0.6443
# Epoch 39/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.1252 - accuracy: 0.9509 - val_loss: 1.1309 - val_accuracy: 0.6443
# Epoch 40/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.1447 - accuracy: 0.9451 - val_loss: 1.4790 - val_accuracy: 0.5705
# Epoch 41/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.1178 - accuracy: 0.9653 - val_loss: 1.8141 - val_accuracy: 0.5839
# Epoch 42/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0939 - accuracy: 0.9769 - val_loss: 3.1386 - val_accuracy: 0.5235
# Epoch 43/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.1021 - accuracy: 0.9595 - val_loss: 2.0515 - val_accuracy: 0.6510
# Epoch 44/250
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0623 - accuracy: 0.9827 - val_loss: 1.2665 - val_accuracy: 0.7248
# Epoch 45/250
# 22/22 [==============================] - 0s 11ms/step - loss: 0.1643 - accuracy: 0.9480 - val_loss: 2.2807 - val_accuracy: 0.5906
# Epoch 46/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.1601 - accuracy: 0.9393 - val_loss: 3.6647 - val_accuracy: 0.6443
# Epoch 47/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.1461 - accuracy: 0.9480 - val_loss: 3.2930 - val_accuracy: 0.6040
# Epoch 48/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.1264 - accuracy: 0.9422 - val_loss: 4.2939 - val_accuracy: 0.6443
# Epoch 49/250
# 22/22 [==============================] - 0s 14ms/step - loss: 0.1418 - accuracy: 0.9451 - val_loss: 4.2443 - val_accuracy: 0.5235
# Epoch 50/250
# 22/22 [==============================] - 0s 14ms/step - loss: 0.1057 - accuracy: 0.9480 - val_loss: 4.0865 - val_accuracy: 0.5235
# Epoch 51/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0778 - accuracy: 0.9653 - val_loss: 3.9126 - val_accuracy: 0.5436
# Epoch 52/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0735 - accuracy: 0.9653 - val_loss: 3.8965 - val_accuracy: 0.5235
# Epoch 53/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0866 - accuracy: 0.9682 - val_loss: 1.0067 - val_accuracy: 0.6510
# Epoch 54/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0466 - accuracy: 0.9855 - val_loss: 1.7331 - val_accuracy: 0.6913
# Epoch 55/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.1359 - accuracy: 0.9480 - val_loss: 1.7597 - val_accuracy: 0.6711
# Epoch 56/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0695 - accuracy: 0.9769 - val_loss: 1.1516 - val_accuracy: 0.7517
# Epoch 57/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0683 - accuracy: 0.9740 - val_loss: 2.7520 - val_accuracy: 0.5570
# Epoch 58/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.1478 - accuracy: 0.9422 - val_loss: 1.9283 - val_accuracy: 0.5973
# Epoch 59/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.1588 - accuracy: 0.9451 - val_loss: 1.2055 - val_accuracy: 0.7450
# Epoch 60/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0912 - accuracy: 0.9653 - val_loss: 1.2875 - val_accuracy: 0.7383
# Epoch 61/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0973 - accuracy: 0.9798 - val_loss: 3.0039 - val_accuracy: 0.5570
# Epoch 62/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0681 - accuracy: 0.9740 - val_loss: 1.4192 - val_accuracy: 0.7181
# Epoch 63/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0584 - accuracy: 0.9798 - val_loss: 1.7772 - val_accuracy: 0.6510
# Epoch 64/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0501 - accuracy: 0.9827 - val_loss: 1.0358 - val_accuracy: 0.7517
# Epoch 65/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0530 - accuracy: 0.9855 - val_loss: 4.3199 - val_accuracy: 0.5168
# Epoch 66/250
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0716 - accuracy: 0.9682 - val_loss: 5.1696 - val_accuracy: 0.5168
# Epoch 67/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.1178 - accuracy: 0.9451 - val_loss: 3.2471 - val_accuracy: 0.6040
# Epoch 68/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0678 - accuracy: 0.9740 - val_loss: 3.2599 - val_accuracy: 0.6577
# Epoch 69/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0902 - accuracy: 0.9595 - val_loss: 4.1864 - val_accuracy: 0.5906
# Epoch 70/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0450 - accuracy: 0.9855 - val_loss: 4.4336 - val_accuracy: 0.5906
# Epoch 71/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0577 - accuracy: 0.9769 - val_loss: 3.2002 - val_accuracy: 0.6309
# Epoch 72/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0835 - accuracy: 0.9682 - val_loss: 3.0283 - val_accuracy: 0.5705
# Epoch 73/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.1032 - accuracy: 0.9653 - val_loss: 3.5015 - val_accuracy: 0.6376
# Epoch 74/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0960 - accuracy: 0.9653 - val_loss: 3.8171 - val_accuracy: 0.6040
# Epoch 75/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0474 - accuracy: 0.9798 - val_loss: 3.9870 - val_accuracy: 0.5570
# Epoch 76/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0338 - accuracy: 0.9942 - val_loss: 1.3754 - val_accuracy: 0.6711
# Epoch 77/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0370 - accuracy: 0.9855 - val_loss: 1.4438 - val_accuracy: 0.6577
# Epoch 78/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0311 - accuracy: 0.9913 - val_loss: 10.4493 - val_accuracy: 0.5168
# Epoch 79/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0713 - accuracy: 0.9740 - val_loss: 14.1629 - val_accuracy: 0.4899
# Epoch 80/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0531 - accuracy: 0.9769 - val_loss: 4.8005 - val_accuracy: 0.5101
# Epoch 81/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0617 - accuracy: 0.9711 - val_loss: 5.0183 - val_accuracy: 0.5570
# Epoch 82/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.1110 - accuracy: 0.9595 - val_loss: 4.6311 - val_accuracy: 0.5235
# Epoch 83/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0645 - accuracy: 0.9769 - val_loss: 2.5974 - val_accuracy: 0.6376
# Epoch 84/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0619 - accuracy: 0.9711 - val_loss: 5.1058 - val_accuracy: 0.5369
# Epoch 85/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0135 - accuracy: 0.9971 - val_loss: 3.9419 - val_accuracy: 0.6040
# Epoch 86/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0289 - accuracy: 0.9855 - val_loss: 2.5244 - val_accuracy: 0.6242
# Epoch 87/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0278 - accuracy: 0.9913 - val_loss: 7.8877 - val_accuracy: 0.5101
# Epoch 88/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0335 - accuracy: 0.9884 - val_loss: 3.4511 - val_accuracy: 0.6309
# Epoch 89/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0427 - accuracy: 0.9855 - val_loss: 7.0140 - val_accuracy: 0.5168
# Epoch 90/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.1137 - accuracy: 0.9624 - val_loss: 1.0434 - val_accuracy: 0.7181
# Epoch 91/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.1366 - accuracy: 0.9624 - val_loss: 9.8776 - val_accuracy: 0.4899
# Epoch 92/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0602 - accuracy: 0.9769 - val_loss: 1.4116 - val_accuracy: 0.6510
# Epoch 93/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0532 - accuracy: 0.9798 - val_loss: 0.9137 - val_accuracy: 0.6779
# Epoch 94/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0545 - accuracy: 0.9798 - val_loss: 1.1066 - val_accuracy: 0.7181
# Epoch 95/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0697 - accuracy: 0.9682 - val_loss: 0.8620 - val_accuracy: 0.7584
# Epoch 96/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0337 - accuracy: 0.9884 - val_loss: 2.6956 - val_accuracy: 0.6309
# Epoch 97/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0261 - accuracy: 0.9884 - val_loss: 3.1135 - val_accuracy: 0.6107
# Epoch 98/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0544 - accuracy: 0.9740 - val_loss: 2.4877 - val_accuracy: 0.6376
# Epoch 99/250
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0204 - accuracy: 0.9971 - val_loss: 2.9188 - val_accuracy: 0.6040
# Epoch 100/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0464 - accuracy: 0.9827 - val_loss: 3.9949 - val_accuracy: 0.5705
# Epoch 101/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0677 - accuracy: 0.9624 - val_loss: 2.5065 - val_accuracy: 0.6174
# Epoch 102/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0252 - accuracy: 0.9913 - val_loss: 4.6845 - val_accuracy: 0.5503
# Epoch 103/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0772 - accuracy: 0.9740 - val_loss: 5.7573 - val_accuracy: 0.5772
# Epoch 104/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0745 - accuracy: 0.9740 - val_loss: 2.0399 - val_accuracy: 0.7047
# Epoch 105/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0390 - accuracy: 0.9913 - val_loss: 3.8916 - val_accuracy: 0.6644
# Epoch 106/250
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0712 - accuracy: 0.9711 - val_loss: 2.0510 - val_accuracy: 0.7181
# Epoch 107/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0338 - accuracy: 0.9884 - val_loss: 1.5549 - val_accuracy: 0.6980
# Epoch 108/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0188 - accuracy: 0.9942 - val_loss: 4.2216 - val_accuracy: 0.6510
# Epoch 109/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0550 - accuracy: 0.9798 - val_loss: 2.4984 - val_accuracy: 0.7047
# Epoch 110/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0648 - accuracy: 0.9769 - val_loss: 1.4634 - val_accuracy: 0.6846
# Epoch 111/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0443 - accuracy: 0.9769 - val_loss: 1.7533 - val_accuracy: 0.6443
# Epoch 112/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0266 - accuracy: 0.9913 - val_loss: 1.3500 - val_accuracy: 0.7248
# Epoch 113/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0626 - accuracy: 0.9827 - val_loss: 4.3618 - val_accuracy: 0.5235
# Epoch 114/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0408 - accuracy: 0.9884 - val_loss: 2.0004 - val_accuracy: 0.5973
# Epoch 115/250
# 22/22 [==============================] - 0s 14ms/step - loss: 0.1004 - accuracy: 0.9595 - val_loss: 1.9298 - val_accuracy: 0.5973
# Epoch 116/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0646 - accuracy: 0.9740 - val_loss: 1.2364 - val_accuracy: 0.6913
# Epoch 117/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0710 - accuracy: 0.9740 - val_loss: 4.7391 - val_accuracy: 0.5973
# Epoch 118/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0252 - accuracy: 0.9913 - val_loss: 3.8262 - val_accuracy: 0.5705
# Epoch 119/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0393 - accuracy: 0.9855 - val_loss: 5.5774 - val_accuracy: 0.5302
# Epoch 120/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0363 - accuracy: 0.9884 - val_loss: 8.8666 - val_accuracy: 0.5503
# Epoch 121/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0458 - accuracy: 0.9855 - val_loss: 5.3437 - val_accuracy: 0.5638
# Epoch 122/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0161 - accuracy: 0.9971 - val_loss: 4.0299 - val_accuracy: 0.5638
# Epoch 123/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0193 - accuracy: 0.9942 - val_loss: 3.6396 - val_accuracy: 0.5839
# Epoch 124/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0278 - accuracy: 0.9971 - val_loss: 1.9089 - val_accuracy: 0.7047
# Epoch 125/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0568 - accuracy: 0.9798 - val_loss: 1.2812 - val_accuracy: 0.7315
# Epoch 126/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0746 - accuracy: 0.9740 - val_loss: 6.8838 - val_accuracy: 0.5839
# Epoch 127/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0844 - accuracy: 0.9624 - val_loss: 6.7115 - val_accuracy: 0.5302
# Epoch 128/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.1021 - accuracy: 0.9682 - val_loss: 1.1800 - val_accuracy: 0.6577
# Epoch 129/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0655 - accuracy: 0.9769 - val_loss: 1.7605 - val_accuracy: 0.6376
# Epoch 130/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0864 - accuracy: 0.9595 - val_loss: 4.3282 - val_accuracy: 0.6376
# Epoch 131/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0540 - accuracy: 0.9740 - val_loss: 2.7315 - val_accuracy: 0.6510
# Epoch 132/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0322 - accuracy: 0.9855 - val_loss: 2.3055 - val_accuracy: 0.6846
# Epoch 133/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0350 - accuracy: 0.9855 - val_loss: 1.4670 - val_accuracy: 0.7315
# Epoch 134/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0134 - accuracy: 0.9942 - val_loss: 1.6471 - val_accuracy: 0.6779
# Epoch 135/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0299 - accuracy: 0.9913 - val_loss: 1.0677 - val_accuracy: 0.7047
# Epoch 136/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0474 - accuracy: 0.9798 - val_loss: 1.5404 - val_accuracy: 0.6913
# Epoch 137/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0176 - accuracy: 0.9971 - val_loss: 2.5374 - val_accuracy: 0.6309
# Epoch 138/250
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0228 - accuracy: 0.9971 - val_loss: 1.7269 - val_accuracy: 0.6913
# Epoch 139/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0231 - accuracy: 0.9884 - val_loss: 2.1946 - val_accuracy: 0.6174
# Epoch 140/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0301 - accuracy: 0.9942 - val_loss: 1.3861 - val_accuracy: 0.6309
# Epoch 141/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0110 - accuracy: 0.9942 - val_loss: 1.1787 - val_accuracy: 0.6980
# Epoch 142/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 1.1772 - val_accuracy: 0.6980
# Epoch 143/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0134 - accuracy: 1.0000 - val_loss: 1.3148 - val_accuracy: 0.7181
# Epoch 144/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0202 - accuracy: 0.9942 - val_loss: 1.3429 - val_accuracy: 0.7248
# Epoch 145/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0589 - accuracy: 0.9798 - val_loss: 2.8423 - val_accuracy: 0.6510
# Epoch 146/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0906 - accuracy: 0.9769 - val_loss: 2.4887 - val_accuracy: 0.6980
# Epoch 147/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0263 - accuracy: 0.9884 - val_loss: 3.4000 - val_accuracy: 0.6846
# Epoch 148/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0564 - accuracy: 0.9711 - val_loss: 3.2039 - val_accuracy: 0.6644
# Epoch 149/250
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0221 - accuracy: 0.9942 - val_loss: 7.4758 - val_accuracy: 0.5705
# Epoch 150/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0173 - accuracy: 0.9971 - val_loss: 10.4656 - val_accuracy: 0.5168
# Epoch 151/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0533 - accuracy: 0.9913 - val_loss: 6.4935 - val_accuracy: 0.5772
# Epoch 152/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0457 - accuracy: 0.9827 - val_loss: 5.5466 - val_accuracy: 0.6242
# Epoch 153/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0555 - accuracy: 0.9798 - val_loss: 9.9575 - val_accuracy: 0.5436
# Epoch 154/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0381 - accuracy: 0.9884 - val_loss: 10.4070 - val_accuracy: 0.5101
# Epoch 155/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0166 - accuracy: 0.9971 - val_loss: 5.8195 - val_accuracy: 0.5168
# Epoch 156/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0468 - accuracy: 0.9827 - val_loss: 7.7140 - val_accuracy: 0.5235
# Epoch 157/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0219 - accuracy: 0.9913 - val_loss: 3.5797 - val_accuracy: 0.6846
# Epoch 158/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0115 - accuracy: 0.9942 - val_loss: 3.1728 - val_accuracy: 0.6711
# Epoch 159/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0508 - accuracy: 0.9884 - val_loss: 2.0379 - val_accuracy: 0.6376
# Epoch 160/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0500 - accuracy: 0.9740 - val_loss: 5.2326 - val_accuracy: 0.4966
# Epoch 161/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0328 - accuracy: 0.9913 - val_loss: 1.6550 - val_accuracy: 0.5839
# Epoch 162/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0344 - accuracy: 0.9913 - val_loss: 4.9235 - val_accuracy: 0.5705
# Epoch 163/250
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0494 - accuracy: 0.9855 - val_loss: 10.4616 - val_accuracy: 0.5503
# Epoch 164/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0150 - accuracy: 0.9942 - val_loss: 10.4766 - val_accuracy: 0.5436
# Epoch 165/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0202 - accuracy: 0.9913 - val_loss: 9.3759 - val_accuracy: 0.5168
# Epoch 166/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 5.0630 - val_accuracy: 0.5705
# Epoch 167/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0372 - accuracy: 0.9913 - val_loss: 3.8579 - val_accuracy: 0.5705
# Epoch 168/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0273 - accuracy: 0.9884 - val_loss: 3.8480 - val_accuracy: 0.7114
# Epoch 169/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0890 - accuracy: 0.9682 - val_loss: 6.8827 - val_accuracy: 0.5436
# Epoch 170/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0887 - accuracy: 0.9798 - val_loss: 1.7236 - val_accuracy: 0.6846
# Epoch 171/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0561 - accuracy: 0.9855 - val_loss: 1.5760 - val_accuracy: 0.7181
# Epoch 172/250
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0217 - accuracy: 0.9971 - val_loss: 2.3780 - val_accuracy: 0.7383
# Epoch 173/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0235 - accuracy: 0.9913 - val_loss: 2.6880 - val_accuracy: 0.7047
# Epoch 174/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0301 - accuracy: 0.9884 - val_loss: 3.6572 - val_accuracy: 0.6846
# Epoch 175/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0397 - accuracy: 0.9855 - val_loss: 3.4746 - val_accuracy: 0.7181
# Epoch 176/250
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0203 - accuracy: 0.9884 - val_loss: 2.8152 - val_accuracy: 0.5839
# Epoch 177/250
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0128 - accuracy: 0.9971 - val_loss: 3.7235 - val_accuracy: 0.5839
# Epoch 178/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0217 - accuracy: 0.9942 - val_loss: 2.4315 - val_accuracy: 0.6443
# Epoch 179/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0245 - accuracy: 0.9913 - val_loss: 1.3951 - val_accuracy: 0.6577
# Epoch 180/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0127 - accuracy: 0.9971 - val_loss: 2.5786 - val_accuracy: 0.6913
# Epoch 181/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0531 - accuracy: 0.9798 - val_loss: 3.0052 - val_accuracy: 0.6980
# Epoch 182/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0239 - accuracy: 0.9884 - val_loss: 5.7575 - val_accuracy: 0.5235
# Epoch 183/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0384 - accuracy: 0.9884 - val_loss: 1.9531 - val_accuracy: 0.6577
# Epoch 184/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0945 - accuracy: 0.9682 - val_loss: 1.9602 - val_accuracy: 0.6644
# Epoch 185/250
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0546 - accuracy: 0.9827 - val_loss: 5.0019 - val_accuracy: 0.6376
# Epoch 186/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0695 - accuracy: 0.9682 - val_loss: 3.7933 - val_accuracy: 0.6577
# Epoch 187/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0377 - accuracy: 0.9827 - val_loss: 3.2402 - val_accuracy: 0.6980
# Epoch 188/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0465 - accuracy: 0.9827 - val_loss: 2.4608 - val_accuracy: 0.7114
# Epoch 189/250
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0584 - accuracy: 0.9855 - val_loss: 2.8436 - val_accuracy: 0.6644
# Epoch 190/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0435 - accuracy: 0.9798 - val_loss: 3.1873 - val_accuracy: 0.6846
# Epoch 191/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0168 - accuracy: 0.9942 - val_loss: 1.6347 - val_accuracy: 0.7181
# Epoch 192/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0225 - accuracy: 0.9942 - val_loss: 3.4115 - val_accuracy: 0.6644
# Epoch 193/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0510 - accuracy: 0.9769 - val_loss: 3.4410 - val_accuracy: 0.6309
# Epoch 194/250
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 2.7052 - val_accuracy: 0.6711
# Epoch 195/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0235 - accuracy: 0.9942 - val_loss: 1.6029 - val_accuracy: 0.7047
# Epoch 196/250
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0174 - accuracy: 0.9971 - val_loss: 1.5684 - val_accuracy: 0.6913
# Epoch 197/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0345 - accuracy: 0.9827 - val_loss: 2.3554 - val_accuracy: 0.6174
# Epoch 198/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0243 - accuracy: 0.9942 - val_loss: 3.5274 - val_accuracy: 0.6107
# Epoch 199/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 2.1317 - val_accuracy: 0.6443
# Epoch 200/250
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0215 - accuracy: 0.9913 - val_loss: 2.0036 - val_accuracy: 0.6980
# Epoch 201/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0225 - accuracy: 0.9884 - val_loss: 1.4830 - val_accuracy: 0.6846
# Epoch 202/250
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0292 - accuracy: 0.9827 - val_loss: 1.8446 - val_accuracy: 0.6510
# Epoch 203/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0288 - accuracy: 0.9913 - val_loss: 4.1295 - val_accuracy: 0.6107
# Epoch 204/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0227 - accuracy: 0.9942 - val_loss: 1.6381 - val_accuracy: 0.7181
# Epoch 205/250
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0465 - accuracy: 0.9827 - val_loss: 3.6867 - val_accuracy: 0.5772
# Epoch 206/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0438 - accuracy: 0.9827 - val_loss: 2.8664 - val_accuracy: 0.6443
# Epoch 207/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0203 - accuracy: 0.9913 - val_loss: 2.5931 - val_accuracy: 0.6711
# Epoch 208/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0630 - accuracy: 0.9711 - val_loss: 3.4835 - val_accuracy: 0.6779
# Epoch 209/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0307 - accuracy: 0.9855 - val_loss: 2.8959 - val_accuracy: 0.7047
# Epoch 210/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0252 - accuracy: 0.9913 - val_loss: 2.1572 - val_accuracy: 0.6913
# Epoch 211/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0579 - accuracy: 0.9855 - val_loss: 4.6731 - val_accuracy: 0.5503
# Epoch 212/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0265 - accuracy: 0.9942 - val_loss: 2.5706 - val_accuracy: 0.6174
# Epoch 213/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 2.7071 - val_accuracy: 0.5839
# Epoch 214/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0613 - accuracy: 0.9827 - val_loss: 3.0213 - val_accuracy: 0.6309
# Epoch 215/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0240 - accuracy: 0.9884 - val_loss: 7.7410 - val_accuracy: 0.5369
# Epoch 216/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0203 - accuracy: 0.9855 - val_loss: 11.5044 - val_accuracy: 0.4966
# Epoch 217/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0319 - accuracy: 0.9913 - val_loss: 5.2092 - val_accuracy: 0.6174
# Epoch 218/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0135 - accuracy: 0.9942 - val_loss: 3.8849 - val_accuracy: 0.5772
# Epoch 219/250
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0409 - accuracy: 0.9855 - val_loss: 2.8362 - val_accuracy: 0.6577
# Epoch 220/250
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0275 - accuracy: 0.9913 - val_loss: 2.6323 - val_accuracy: 0.6510
# Epoch 221/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0374 - accuracy: 0.9855 - val_loss: 2.6165 - val_accuracy: 0.6779
# Epoch 222/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0115 - accuracy: 0.9971 - val_loss: 1.3946 - val_accuracy: 0.6913
# Epoch 223/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0075 - accuracy: 0.9971 - val_loss: 2.1629 - val_accuracy: 0.6846
# Epoch 224/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 1.7541 - val_accuracy: 0.7114
# Epoch 225/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0162 - accuracy: 0.9971 - val_loss: 1.3510 - val_accuracy: 0.7047
# Epoch 226/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0209 - accuracy: 0.9913 - val_loss: 2.4520 - val_accuracy: 0.6510
# Epoch 227/250
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0276 - accuracy: 0.9971 - val_loss: 1.3497 - val_accuracy: 0.6779
# Epoch 228/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.1525 - accuracy: 0.9509 - val_loss: 2.3381 - val_accuracy: 0.5973
# Epoch 229/250
# 22/22 [==============================] - 0s 14ms/step - loss: 0.1025 - accuracy: 0.9624 - val_loss: 5.9015 - val_accuracy: 0.5906
# Epoch 230/250
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0579 - accuracy: 0.9769 - val_loss: 5.0720 - val_accuracy: 0.6577
# Epoch 231/250
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0775 - accuracy: 0.9769 - val_loss: 9.4223 - val_accuracy: 0.5302
# Epoch 232/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0573 - accuracy: 0.9798 - val_loss: 10.1982 - val_accuracy: 0.5168
# Epoch 233/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0237 - accuracy: 0.9971 - val_loss: 9.9347 - val_accuracy: 0.5503
# Epoch 234/250
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0940 - accuracy: 0.9538 - val_loss: 5.1206 - val_accuracy: 0.5906
# Epoch 235/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0241 - accuracy: 0.9913 - val_loss: 1.7251 - val_accuracy: 0.7248
# Epoch 236/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0261 - accuracy: 0.9913 - val_loss: 1.3515 - val_accuracy: 0.7517
# Epoch 237/250
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0160 - accuracy: 0.9942 - val_loss: 1.9606 - val_accuracy: 0.7450
# Epoch 238/250
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0368 - accuracy: 0.9884 - val_loss: 3.4623 - val_accuracy: 0.6107
# Epoch 239/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0471 - accuracy: 0.9884 - val_loss: 5.0422 - val_accuracy: 0.5638
# Epoch 240/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0420 - accuracy: 0.9884 - val_loss: 8.5559 - val_accuracy: 0.4966
# Epoch 241/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0572 - accuracy: 0.9798 - val_loss: 1.6392 - val_accuracy: 0.7114
# Epoch 242/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0779 - accuracy: 0.9711 - val_loss: 4.4030 - val_accuracy: 0.6846
# Epoch 243/250
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0315 - accuracy: 0.9913 - val_loss: 5.1250 - val_accuracy: 0.6443
# Epoch 244/250
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0380 - accuracy: 0.9855 - val_loss: 8.3648 - val_accuracy: 0.5973
# Epoch 245/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0190 - accuracy: 0.9913 - val_loss: 6.3211 - val_accuracy: 0.5906
# Epoch 246/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0173 - accuracy: 0.9942 - val_loss: 6.4119 - val_accuracy: 0.5436
# Epoch 247/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0234 - accuracy: 0.9942 - val_loss: 4.6626 - val_accuracy: 0.5906
# Epoch 248/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0262 - accuracy: 0.9884 - val_loss: 4.5703 - val_accuracy: 0.5705
# Epoch 249/250
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0099 - accuracy: 1.0000 - val_loss: 3.4727 - val_accuracy: 0.5839
# Epoch 250/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0108 - accuracy: 0.9942 - val_loss: 2.1667 - val_accuracy: 0.6443

# %%
import os
import seaborn as sns
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
prediction_NN = model.predict(xTest11)
prediction_NN = np.argmax(prediction_NN, axis=-1)
#Print overall accuracy
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(yTest1, prediction_NN))
#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(yTest1, prediction_NN)
print(cm)
sns.heatmap(cm, annot=True)
# Out:
# Accuracy =  0.6442953020134228
# [[24 49]
#  [ 4 72]]
