# %% [markdown]
# <a href="https://colab.research.google.com/github/rohitsubodh/GAN/blob/main/Untitled8_200.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import keras
import numpy as np
from keras import models
from keras import layers
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score
from sklearn.datasets import make_classification
from matplotlib import pyplot
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import preprocessing
from keras.models import Sequential,Model
from keras.layers import Dense, Dropout,Input, Conv1D, MaxPooling1D, UpSampling1D, concatenate, BatchNormalization, Activation, add
from keras.layers import Embedding,LeakyReLU
from keras.layers import Conv1D, GlobalAveragePooling1D, MaxPooling1D, Flatten, LocallyConnected1D, BatchNormalization
import scipy.signal
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.decomposition import PCA, KernelPCA

# %%
data = pd.read_excel('/content/PPG_new.xlsx',sheet_name='0-1')
target = pd.read_excel('/content/PPG_new.xlsx',sheet_name='target 0-1')

# %%
# data1=data
# kpca=KernelPCA(kernel="rbf",fit_inverse_transform=True, gamma=10)
# data=kpca.fit_transform(data)

# %%
# data1=data
# kpca=KernelPCA(kernel="rbf",fit_inverse_transform=True, gamma=10)
# data=kpca.fit_transform(data)
# data.shape

# %%
# x= data[0,:]
x=data.iloc[0,:]
plt.plot(x)
plt.show
data1=data

# %%
# from sklearn.preprocessing import StandardScaler,MinMaxScaler

# data = StandardScaler().fit_transform(data)
# data=MinMaxScaler().fit_transform(data)

# %%
# Applying median filter
data=scipy.signal.medfilt(data)
data
x= data[0,:]
plt.plot(x)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
# Design of low pass chebyshev filter
sos= scipy.signal.cheby2(4, 10, 25, 'low', fs=1000, output='sos')
sos
# Out:
# array([[ 0.26741176, -0.49141861,  0.26741176,  1.        , -1.6346899 ,
#          0.69069827],
#        [ 1.        , -1.97118242,  1.        ,  1.        , -1.92658177,
#          0.94891457]])

# %%
data= scipy.signal.sosfilt(sos, data) # applying chebyshev filter
x= data[0,:]
plt.plot(x)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
# Applying backward forward filter
b, a = scipy.signal.butter(8, 0.125) # filter design

data = scipy.signal.filtfilt(b, a, data, method="gust")

x= data[0,:]
plt.plot(x)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
data1=data
kpca=KernelPCA(kernel="rbf",fit_inverse_transform=True, gamma=10)
data=kpca.fit_transform(data)
data.shape
# Out:
# (495, 494)

# %%
x= data[0,:]
plt.plot(x)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
# from sklearn.preprocessing import StandardScaler

# data = StandardScaler().fit_transform(data)

# xTrain1 = scaler.transform(xTrain1)

# xTest1 = scaler.transform(xTest1)

# %%
from sklearn.model_selection import train_test_split
xTrain1, xTest1, yTrain1, yTest1 = train_test_split(data, target, test_size = 0.3, random_state = 42)

# %%
# from sklearn.preprocessing import StandardScaler

# scaler = StandardScaler().fit(xTrain1)

# xTrain1 = scaler.transform(xTrain1)

# xTest1 = scaler.transform(xTest1)

# %%
xTrain11 = np.expand_dims(xTrain1, axis=2)
yTrain11 = tf.keras.utils.to_categorical(yTrain1, num_classes=2)
xTest11 =  np.expand_dims(xTest1, axis=2)
yTest11 = tf.keras.utils.to_categorical(yTest1, num_classes=2)

# %%
# input_shape = (2100, 1)
input_shape = (494, 1)

# %%
  #   x = 64
  # #  from keras
  #   inputs = Input(input_shape)
  #   conv1 = Conv1D(x,3, activation='relu', padding='same')(inputs)
  #   conv1 = BatchNormalization()(conv1)
  #   conv1 = Conv1D(x,3, activation='relu', padding='same')(conv1)
  #   conv1 = BatchNormalization()(conv1)
  #   pool1 = MaxPooling1D(pool_size=2)(conv1)

  #   conv2 = Conv1D(x*2,3, activation='relu', padding='same')(pool1)
  #   conv2 = BatchNormalization()(conv2)
  #   conv2 = Conv1D(x*2,3, activation='relu', padding='same')(conv2)
  #   conv2 = BatchNormalization()(conv2)
  #   pool2 = MaxPooling1D(pool_size=2)(conv2)

  #   conv3 = Conv1D(x*4,3, activation='relu', padding='same')(pool2)
  #   conv3 = BatchNormalization()(conv3)
  #   conv3 = Conv1D(x*4,3, activation='relu', padding='same')(conv3)
  #   conv3 = BatchNormalization()(conv3)
  #   pool3 = MaxPooling1D(pool_size=2)(conv3)

  #   conv4 = Conv1D(x*8,3, activation='relu', padding='same')(pool3)
  #   conv4 = BatchNormalization()(conv4)
  #   conv4 = Conv1D(x*8,3, activation='relu', padding='same')(conv4)
  #   conv4 = BatchNormalization()(conv4)
  #   pool4 = MaxPooling1D(pool_size=2)(conv4)

  #   conv5 = Conv1D(x*16, 3, activation='relu', padding='same')(pool4)
  #   conv5 = BatchNormalization()(conv5)
  #   conv5 = Conv1D(x*16, 3, activation='relu', padding='same')(conv5)
  #   conv5 = BatchNormalization()(conv5)

  #   up6 = concatenate([UpSampling1D(size=2)(conv5), conv4], axis=2)
  #   conv6 = Conv1D(x*8, 3, activation='relu', padding='same')(up6)
  #   conv6 = BatchNormalization()(conv6)
  #   conv6 = Conv1D(x*8, 3, activation='relu', padding='same')(conv6)
  #   conv6 = BatchNormalization()(conv6)
    
  #   up7 = concatenate([UpSampling1D(size=2)(conv6), conv3], axis=2)
  #   conv7 = Conv1D(x*4, 3, activation='relu', padding='same')(up7)
  #   conv7 = BatchNormalization()(conv7)
  #   conv7 = Conv1D(x*4, 3, activation='relu', padding='same')(conv7)
  #   conv7 = BatchNormalization()(conv7)

  #   up8 = concatenate([UpSampling1D(size=2)(conv7), conv2], axis=2)
  #   conv8 = Conv1D(x*2, 3, activation='relu', padding='same')(up8)
  #   conv8 = BatchNormalization()(conv8)
  #   conv8 = Conv1D(x*2, 3, activation='relu', padding='same')(conv8)
  #   conv8 = BatchNormalization()(conv8)

  #   up9 = concatenate([UpSampling1D(size=2)(conv8), conv1], axis=2)
  #   conv9 = Conv1D(x, 3, activation='relu', padding='same')(up9)
  #   conv9 = BatchNormalization()(conv9)
  #   conv9 = Conv1D(x, 3, activation='relu', padding='same')(conv9)
  #   conv9 = BatchNormalization()(conv9)

  #   conv10 = Conv1D(1, 1)(conv9)

  #   model = Model(inputs=[inputs], outputs=[conv10])
  #   # model.compile(loss='mean_absolute_error',optimizer='adam',metrics=['mean_squared_error'], loss_weights=[1., 0.9, 0.8, 0.7, 0.6])                                                         
  #   model.compile(loss='categorical_crossentropy',
  #                   optimizer='adam',
  #                   metrics=['accuracy'])

  #   # checkpoint1_ = ModelCheckpoint(os.path.join('models','{}_model1_fold{}.h5'.format(mdlName1,foldname)), verbose=1, monitor='val_out_loss',save_best_only=True, mode='auto')  
  #                                                                       # train approximation network for 100 epochs
  #   # history1 = mdl1.fit(X_train,{'out': Y_train['out'], 'level1': Y_train['level1'], 'level2':Y_train['level2'], 'level3':Y_train['level3'] , 'level4':Y_train['level4']},epochs=100,batch_size=256,validation_data=(X_val,{'out': Y_val['out'], 'level1': Y_val['level1'], 'level2':Y_val['level2'], 'level3':Y_val['level3'] , 'level4':Y_val['level4']}),callbacks=[checkpoint1_],verbose=1)
  #   history = model.fit(xTrain1, yTrain1, validation_split=0.3, epochs=200, batch_size=20, verbose=2)

# %%
#CNN Model

model = Sequential()
model.add(Conv1D(32, 3, activation='relu', input_shape=input_shape[0:]))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.1))
model.add(Conv1D(64, 3, activation='relu', name="my_intermediate_layer"))
model.add(MaxPooling1D(3))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.1))
model.add(Conv1D(128, 3, activation='relu'))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.1))
model.add(Conv1D(256, 3, activation='relu'))
model.add(GlobalAveragePooling1D())
model.add(Dropout(0.5))
model.add(Dense(100, name="dense"))
model.add(Dense(2, activation='softmax', name="dense1"))
model.compile(loss='categorical_crossentropy',
                    optimizer='adam',
                    metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 492, 32)           128
# _________________________________________________________________
# batch_normalization (BatchNo (None, 492, 32)           128
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 492, 32)           0
# _________________________________________________________________
# my_intermediate_layer (Conv1 (None, 490, 64)           6208
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 163, 64)           0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 163, 64)           256
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 163, 64)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 161, 128)          24704
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 161, 128)          512
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 161, 128)          0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 159, 256)          98560
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 256)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 100)               25700
# _________________________________________________________________
# dense1 (Dense)               (None, 2)                 202
# =================================================================
# Total params: 156,398
# Trainable params: 155,950
# Non-trainable params: 448
# _________________________________________________________________

# %%
# from sklearn.model_selection import train_test_split
# xTrain1, xTest1, yTrain1, yTest1 = train_test_split(data, target, test_size = 0.3, random_state = 42)

# xTrain1.shape, yTest1.shape

# xTrain11 = np.expand_dims(xTrain1, axis=2)
# yTrain11 = tf.keras.utils.to_categorical(yTrain1, num_classes=2)
# xTest11 =  np.expand_dims(xTest1, axis=2)
# yTest11 = tf.keras.utils.to_categorical(yTest1, num_classes=2)

# input_shape = (2100, 1)

# model = Sequential()

# model.add(Dense(128, activation='relu', input_shape=(2100, ) ))
# #model.add(Dropout(0.2))
# model.add(BatchNormalization())

# model.add(Dense(64, activation='relu', kernel_regularizer='l2', kernel_initializer='he_uniform'))
# model.add(BatchNormalization())
# model.add(Dropout(0.5))
# model.add(Dense(32, activation='relu', kernel_regularizer='l2', kernel_initializer='he_uniform'))
# model.add(BatchNormalization())
# model.add(Dropout(0.1))
# model.add(Dense(16, activation='relu', kernel_regularizer='l2', kernel_initializer='he_uniform'))
# model.add(BatchNormalization())
# model.add(Dropout(0.1))
# #model.add(Dense(16, activation='relu', kernel_regularizer='l2'))
# #model.add(Dropout(0.05))
# #model.add(Dense(64, activation='relu'))#

# model.add(Dense(1, activation='sigmoid')) 
# opt = tf.keras.optimizers.Adam(learning_rate=.005)
# model.compile(loss='binary_crossentropy',
#               optimizer= opt,
#                metrics=['accuracy'])
# model.summary()               
# history = model.fit(xTrain1, yTrain1, validation_split=0.3, epochs=200, batch_size=20, verbose=2)

# # model.evaluate(x=xTest1, y=yTest1, verbose=2)

# # import os
# # import seaborn as sns
# # #plot the training and validation accuracy and loss at each epoch
# # loss = history.history['loss']
# # val_loss = history.history['val_loss']
# # epochs = range(1, len(loss) + 1)
# # plt.plot(loss[10:], 'b', label='Training loss')
# # plt.plot(val_loss[10:], 'g', label='Validation loss')
# # plt.title('Training and validation loss')
# # plt.xlabel('Epochs')
# # plt.ylabel('Loss')
# # plt.legend()
# # plt.show()

# # acc = history.history['accuracy']
# # val_acc = history.history['val_accuracy']
# # plt.plot(epochs, acc, 'r', label='Training acc')
# # plt.plot(epochs, val_acc, 'c', label='Validation acc')
# # plt.title('Training and validation accuracy')
# # plt.xlabel('Epochs')
# # plt.ylabel('Accuracy')
# # plt.legend()
# # plt.show()

# %%
from keras.callbacks import EarlyStopping
#set early stopping monitor so the model stops training when it won't improve anymore
early_stopping_monitor = EarlyStopping(patience=500)

#train model
history=model.fit(xTrain11, yTrain11, validation_data = (xTest11, yTest11), epochs=200, batch_size=16)
# Out:
# Epoch 1/200
# 22/22 [==============================] - 0s 16ms/step - loss: 9.0259e-04 - accuracy: 1.0000 - val_loss: 1.7041 - val_accuracy: 0.7114
# Epoch 2/200
# 22/22 [==============================] - 0s 14ms/step - loss: 7.7249e-04 - accuracy: 1.0000 - val_loss: 1.6848 - val_accuracy: 0.7383
# Epoch 3/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.7394 - val_accuracy: 0.7450
# Epoch 4/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.6004 - val_accuracy: 0.7517
# Epoch 5/200
# 22/22 [==============================] - 0s 14ms/step - loss: 6.7356e-04 - accuracy: 1.0000 - val_loss: 1.5522 - val_accuracy: 0.7248
# Epoch 6/200
# 22/22 [==============================] - 0s 14ms/step - loss: 5.8676e-04 - accuracy: 1.0000 - val_loss: 1.6325 - val_accuracy: 0.7383
# Epoch 7/200
# 22/22 [==============================] - 0s 13ms/step - loss: 7.8579e-04 - accuracy: 1.0000 - val_loss: 1.8034 - val_accuracy: 0.7248
# Epoch 8/200
# 22/22 [==============================] - 0s 13ms/step - loss: 2.7224e-04 - accuracy: 1.0000 - val_loss: 2.1078 - val_accuracy: 0.7315
# Epoch 9/200
# 22/22 [==============================] - 0s 13ms/step - loss: 2.0682e-04 - accuracy: 1.0000 - val_loss: 2.0704 - val_accuracy: 0.7383
# Epoch 10/200
# 22/22 [==============================] - 0s 13ms/step - loss: 3.5639e-04 - accuracy: 1.0000 - val_loss: 2.0150 - val_accuracy: 0.7450
# Epoch 11/200
# 22/22 [==============================] - 0s 13ms/step - loss: 4.4077e-04 - accuracy: 1.0000 - val_loss: 1.8693 - val_accuracy: 0.7450
# Epoch 12/200
# 22/22 [==============================] - 0s 14ms/step - loss: 5.0369e-04 - accuracy: 1.0000 - val_loss: 1.9311 - val_accuracy: 0.7450
# Epoch 13/200
# 22/22 [==============================] - 0s 15ms/step - loss: 3.2864e-04 - accuracy: 1.0000 - val_loss: 1.8782 - val_accuracy: 0.7450
# Epoch 14/200
# 22/22 [==============================] - 0s 13ms/step - loss: 2
200
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0329 - accuracy: 0.9913 - val_loss: 36.2697 - val_accuracy: 0.5101
# Epoch 104/200
# 22/22 [==============================] - 0s 12ms/step - loss: 0.1208 - accuracy: 0.9740 - val_loss: 6.9120 - val_accuracy: 0.6913
# Epoch 105/200
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0965 - accuracy: 0.9711 - val_loss: 6.8384 - val_accuracy: 0.6309
# Epoch 106/200
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0145 - accuracy: 0.9971 - val_loss: 6.3698 - val_accuracy: 0.6376
# Epoch 107/200
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 4.3851 - val_accuracy: 0.6577
# Epoch 108/200
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 3.9448 - val_accuracy: 0.6846
# Epoch 109/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0049 - accuracy: 0.9971 - val_loss: 3.2273 - val_accuracy: 0.6644
# Epoch 110/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 2.7132 - val_accuracy: 0.6913
# Epoch 111/200
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 3.1482 - val_accuracy: 0.6846
# Epoch 112/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 2.9994 - val_accuracy: 0.6913
# Epoch 113/200
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0072 - accuracy: 0.9971 - val_loss: 2.6215 - val_accuracy: 0.7047
# Epoch 114/200
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 2.7260 - val_accuracy: 0.6711
# Epoch 115/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 2.7591 - val_accuracy: 0.6779
# Epoch 116/200
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0072 - accuracy: 0.9971 - val_loss: 3.0841 - val_accuracy: 0.6577
# Epoch 117/200
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0039 - accuracy: 0.9971 - val_loss: 2.7142 - val_accuracy: 0.6846
# Epoch 118/200
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 2.7196 - val_accuracy: 0.6846
# Epoch 119/200
# 22/22 [==============================] - 0s 13ms/step - loss: 7.8489e-04 - accuracy: 1.0000 - val_loss: 2.6371 - val_accuracy: 0.6711
# Epoch 120/200
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 2.4325 - val_accuracy: 0.6711
# Epoch 121/200
# 22/22 [==============================] - 0s 13ms/step - loss: 8.0434e-04 - accuracy: 1.0000 - val_loss: 2.3162 - val_accuracy: 0.7047
# Epoch 122/200
# 22/22 [==============================] - 0s 14ms/step - loss: 5.0056e-04 - accuracy: 1.0000 - val_loss: 2.3248 - val_accuracy: 0.6980
# Epoch 123/200
# 22/22 [==============================] - 0s 13ms/step - loss: 5.4744e-04 - accuracy: 1.0000 - val_loss: 2.2946 - val_accuracy: 0.6980
# Epoch 124/200
# 22/22 [==============================] - 0s 13ms/step - loss: 2.7525e-04 - accuracy: 1.0000 - val_loss: 2.3389 - val_accuracy: 0.6980
# Epoch 125/200
# 22/22 [==============================] - 0s 13ms/step - loss: 4.3310e-04 - accuracy: 1.0000 - val_loss: 2.3663 - val_accuracy: 0.7047
# Epoch 126/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 2.7795 - val_accuracy: 0.7248
# Epoch 127/200
# 22/22 [==============================] - 0s 13ms/step - loss: 2.4151e-04 - accuracy: 1.0000 - val_loss: 2.8362 - val_accuracy: 0.7248
# Epoch 128/200
# 22/22 [==============================] - 0s 13ms/step - loss: 1.7254e-04 - accuracy: 1.0000 - val_loss: 2.7835 - val_accuracy: 0.7383
# Epoch 129/200
# 22/22 [==============================] - 0s 13ms/step - loss: 2.7159e-04 - accuracy: 1.0000 - val_loss: 2.7410 - val_accuracy: 0.7315
# Epoch 130/200
# 22/22 [==============================] - 0s 15ms/step - loss: 3.6638e-04 - accuracy: 1.0000 - val_loss: 2.6599 - val_accuracy: 0.7181
# Epoch 131/200
# 22/22 [==============================] - 0s 14ms/step - loss: 3.0512e-04 - accuracy: 1.0000 - val_loss: 2.7256 - val_accuracy: 0.7181
# Epoch 132/200
# 22/22 [==============================] - 0s 13ms/step - loss: 2.5952e-04 - accuracy: 1.0000 - val_loss: 2.7108 - val_accuracy: 0.7181
# Epoch 133/200
# 22/22 [==============================] - 0s 13ms/step - loss: 1.2477e-04 - accuracy: 1.0000 - val_loss: 2.7107 - val_accuracy: 0.7181
# Epoch 134/200
# 22/22 [==============================] - 0s 14ms/step - loss: 2.2726e-04 - accuracy: 1.0000 - val_loss: 2.6587 - val_accuracy: 0.7114
# Epoch 135/200
# 22/22 [==============================] - 0s 13ms/step - loss: 5.3720e-04 - accuracy: 1.0000 - val_loss: 2.6776 - val_accuracy: 0.7248
# Epoch 136/200
# 22/22 [==============================] - 0s 14ms/step - loss: 5