# %% [markdown]
# <a href="https://colab.research.google.com/github/rohitsubodh/GAN/blob/main/Untitled8_150.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import keras
import numpy as np
from keras import models
from keras import layers
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score
from sklearn.datasets import make_classification
from matplotlib import pyplot
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import preprocessing
from keras.models import Sequential,Model
from keras.layers import Dense, Dropout,Input, Conv1D, MaxPooling1D, UpSampling1D, concatenate, BatchNormalization, Activation, add
from keras.layers import Embedding,LeakyReLU
from keras.layers import Conv1D, GlobalAveragePooling1D, MaxPooling1D, Flatten, LocallyConnected1D, BatchNormalization
import scipy.signal
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.decomposition import PCA, KernelPCA

# %%
data = pd.read_excel('/content/PPG_new.xlsx',sheet_name='0-1')
target = pd.read_excel('/content/PPG_new.xlsx',sheet_name='target 0-1')

# %%
# data1=data
# kpca=KernelPCA(kernel="rbf",fit_inverse_transform=True, gamma=10)
# data=kpca.fit_transform(data)

# %%
# data1=data
# kpca=KernelPCA(kernel="rbf",fit_inverse_transform=True, gamma=10)
# data=kpca.fit_transform(data)
# data.shape

# %%
# x= data[0,:]
x=data.iloc[0,:]
plt.plot(x)
plt.show
data1=data

# %%
# from sklearn.preprocessing import StandardScaler,MinMaxScaler

# data = StandardScaler().fit_transform(data)
# data=MinMaxScaler().fit_transform(data)

# %%
# Applying median filter
data=scipy.signal.medfilt(data)
data
x= data[0,:]
plt.plot(x)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
# Design of low pass chebyshev filter
sos= scipy.signal.cheby2(4, 10, 25, 'low', fs=1000, output='sos')
sos
# Out:
# array([[ 0.26741176, -0.49141861,  0.26741176,  1.        , -1.6346899 ,
#          0.69069827],
#        [ 1.        , -1.97118242,  1.        ,  1.        , -1.92658177,
#          0.94891457]])

# %%
data= scipy.signal.sosfilt(sos, data) # applying chebyshev filter
x= data[0,:]
plt.plot(x)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
# Applying backward forward filter
b, a = scipy.signal.butter(8, 0.125) # filter design

data = scipy.signal.filtfilt(b, a, data, method="gust")

x= data[0,:]
plt.plot(x)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
data1=data
kpca=KernelPCA(kernel="rbf",fit_inverse_transform=True, gamma=10)
data=kpca.fit_transform(data)
data.shape
# Out:
# (495, 494)

# %%
x= data[0,:]
plt.plot(x)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
# from sklearn.preprocessing import StandardScaler

# data = StandardScaler().fit_transform(data)

# xTrain1 = scaler.transform(xTrain1)

# xTest1 = scaler.transform(xTest1)

# %%
from sklearn.model_selection import train_test_split
xTrain1, xTest1, yTrain1, yTest1 = train_test_split(data, target, test_size = 0.3, random_state = 42)

# %%
# from sklearn.preprocessing import StandardScaler

# scaler = StandardScaler().fit(xTrain1)

# xTrain1 = scaler.transform(xTrain1)

# xTest1 = scaler.transform(xTest1)

# %%
xTrain11 = np.expand_dims(xTrain1, axis=2)
yTrain11 = tf.keras.utils.to_categorical(yTrain1, num_classes=2)
xTest11 =  np.expand_dims(xTest1, axis=2)
yTest11 = tf.keras.utils.to_categorical(yTest1, num_classes=2)

# %%
# input_shape = (2100, 1)
input_shape = (494, 1)

# %%
  #   x = 64
  # #  from keras
  #   inputs = Input(input_shape)
  #   conv1 = Conv1D(x,3, activation='relu', padding='same')(inputs)
  #   conv1 = BatchNormalization()(conv1)
  #   conv1 = Conv1D(x,3, activation='relu', padding='same')(conv1)
  #   conv1 = BatchNormalization()(conv1)
  #   pool1 = MaxPooling1D(pool_size=2)(conv1)

  #   conv2 = Conv1D(x*2,3, activation='relu', padding='same')(pool1)
  #   conv2 = BatchNormalization()(conv2)
  #   conv2 = Conv1D(x*2,3, activation='relu', padding='same')(conv2)
  #   conv2 = BatchNormalization()(conv2)
  #   pool2 = MaxPooling1D(pool_size=2)(conv2)

  #   conv3 = Conv1D(x*4,3, activation='relu', padding='same')(pool2)
  #   conv3 = BatchNormalization()(conv3)
  #   conv3 = Conv1D(x*4,3, activation='relu', padding='same')(conv3)
  #   conv3 = BatchNormalization()(conv3)
  #   pool3 = MaxPooling1D(pool_size=2)(conv3)

  #   conv4 = Conv1D(x*8,3, activation='relu', padding='same')(pool3)
  #   conv4 = BatchNormalization()(conv4)
  #   conv4 = Conv1D(x*8,3, activation='relu', padding='same')(conv4)
  #   conv4 = BatchNormalization()(conv4)
  #   pool4 = MaxPooling1D(pool_size=2)(conv4)

  #   conv5 = Conv1D(x*16, 3, activation='relu', padding='same')(pool4)
  #   conv5 = BatchNormalization()(conv5)
  #   conv5 = Conv1D(x*16, 3, activation='relu', padding='same')(conv5)
  #   conv5 = BatchNormalization()(conv5)

  #   up6 = concatenate([UpSampling1D(size=2)(conv5), conv4], axis=2)
  #   conv6 = Conv1D(x*8, 3, activation='relu', padding='same')(up6)
  #   conv6 = BatchNormalization()(conv6)
  #   conv6 = Conv1D(x*8, 3, activation='relu', padding='same')(conv6)
  #   conv6 = BatchNormalization()(conv6)
    
  #   up7 = concatenate([UpSampling1D(size=2)(conv6), conv3], axis=2)
  #   conv7 = Conv1D(x*4, 3, activation='relu', padding='same')(up7)
  #   conv7 = BatchNormalization()(conv7)
  #   conv7 = Conv1D(x*4, 3, activation='relu', padding='same')(conv7)
  #   conv7 = BatchNormalization()(conv7)

  #   up8 = concatenate([UpSampling1D(size=2)(conv7), conv2], axis=2)
  #   conv8 = Conv1D(x*2, 3, activation='relu', padding='same')(up8)
  #   conv8 = BatchNormalization()(conv8)
  #   conv8 = Conv1D(x*2, 3, activation='relu', padding='same')(conv8)
  #   conv8 = BatchNormalization()(conv8)

  #   up9 = concatenate([UpSampling1D(size=2)(conv8), conv1], axis=2)
  #   conv9 = Conv1D(x, 3, activation='relu', padding='same')(up9)
  #   conv9 = BatchNormalization()(conv9)
  #   conv9 = Conv1D(x, 3, activation='relu', padding='same')(conv9)
  #   conv9 = BatchNormalization()(conv9)

  #   conv10 = Conv1D(1, 1)(conv9)

  #   model = Model(inputs=[inputs], outputs=[conv10])
  #   # model.compile(loss='mean_absolute_error',optimizer='adam',metrics=['mean_squared_error'], loss_weights=[1., 0.9, 0.8, 0.7, 0.6])                                                         
  #   model.compile(loss='categorical_crossentropy',
  #                   optimizer='adam',
  #                   metrics=['accuracy'])

  #   # checkpoint1_ = ModelCheckpoint(os.path.join('models','{}_model1_fold{}.h5'.format(mdlName1,foldname)), verbose=1, monitor='val_out_loss',save_best_only=True, mode='auto')  
  #                                                                       # train approximation network for 100 epochs
  #   # history1 = mdl1.fit(X_train,{'out': Y_train['out'], 'level1': Y_train['level1'], 'level2':Y_train['level2'], 'level3':Y_train['level3'] , 'level4':Y_train['level4']},epochs=100,batch_size=256,validation_data=(X_val,{'out': Y_val['out'], 'level1': Y_val['level1'], 'level2':Y_val['level2'], 'level3':Y_val['level3'] , 'level4':Y_val['level4']}),callbacks=[checkpoint1_],verbose=1)
  #   history = model.fit(xTrain1, yTrain1, validation_split=0.3, epochs=200, batch_size=20, verbose=2)

# %%
#CNN Model

model = Sequential()
model.add(Conv1D(32, 3, activation='relu', input_shape=input_shape[0:]))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.1))
model.add(Conv1D(64, 3, activation='relu', name="my_intermediate_layer"))
model.add(MaxPooling1D(3))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.1))
model.add(Conv1D(128, 3, activation='relu'))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.1))
model.add(Conv1D(256, 3, activation='relu'))
model.add(GlobalAveragePooling1D())
model.add(Dropout(0.5))
model.add(Dense(100, name="dense"))
model.add(Dense(2, activation='softmax', name="dense1"))
model.compile(loss='categorical_crossentropy',
                    optimizer='adam',
                    metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 492, 32)           128
# _________________________________________________________________
# batch_normalization (BatchNo (None, 492, 32)           128
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 492, 32)           0
# _________________________________________________________________
# my_intermediate_layer (Conv1 (None, 490, 64)           6208
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 163, 64)           0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 163, 64)           256
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 163, 64)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 161, 128)          24704
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 161, 128)          512
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 161, 128)          0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 159, 256)          98560
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 256)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 100)               25700
# _________________________________________________________________
# dense1 (Dense)               (None, 2)                 202
# =================================================================
# Total params: 156,398
# Trainable params: 155,950
# Non-trainable params: 448
# _________________________________________________________________

# %%
# from sklearn.model_selection import train_test_split
# xTrain1, xTest1, yTrain1, yTest1 = train_test_split(data, target, test_size = 0.3, random_state = 42)

# xTrain1.shape, yTest1.shape

# xTrain11 = np.expand_dims(xTrain1, axis=2)
# yTrain11 = tf.keras.utils.to_categorical(yTrain1, num_classes=2)
# xTest11 =  np.expand_dims(xTest1, axis=2)
# yTest11 = tf.keras.utils.to_categorical(yTest1, num_classes=2)

# input_shape = (2100, 1)

# model = Sequential()

# model.add(Dense(128, activation='relu', input_shape=(2100, ) ))
# #model.add(Dropout(0.2))
# model.add(BatchNormalization())

# model.add(Dense(64, activation='relu', kernel_regularizer='l2', kernel_initializer='he_uniform'))
# model.add(BatchNormalization())
# model.add(Dropout(0.5))
# model.add(Dense(32, activation='relu', kernel_regularizer='l2', kernel_initializer='he_uniform'))
# model.add(BatchNormalization())
# model.add(Dropout(0.1))
# model.add(Dense(16, activation='relu', kernel_regularizer='l2', kernel_initializer='he_uniform'))
# model.add(BatchNormalization())
# model.add(Dropout(0.1))
# #model.add(Dense(16, activation='relu', kernel_regularizer='l2'))
# #model.add(Dropout(0.05))
# #model.add(Dense(64, activation='relu'))#

# model.add(Dense(1, activation='sigmoid')) 
# opt = tf.keras.optimizers.Adam(learning_rate=.005)
# model.compile(loss='binary_crossentropy',
#               optimizer= opt,
#                metrics=['accuracy'])
# model.summary()               
# history = model.fit(xTrain1, yTrain1, validation_split=0.3, epochs=200, batch_size=20, verbose=2)

# # model.evaluate(x=xTest1, y=yTest1, verbose=2)

# # import os
# # import seaborn as sns
# # #plot the training and validation accuracy and loss at each epoch
# # loss = history.history['loss']
# # val_loss = history.history['val_loss']
# # epochs = range(1, len(loss) + 1)
# # plt.plot(loss[10:], 'b', label='Training loss')
# # plt.plot(val_loss[10:], 'g', label='Validation loss')
# # plt.title('Training and validation loss')
# # plt.xlabel('Epochs')
# # plt.ylabel('Loss')
# # plt.legend()
# # plt.show()

# # acc = history.history['accuracy']
# # val_acc = history.history['val_accuracy']
# # plt.plot(epochs, acc, 'r', label='Training acc')
# # plt.plot(epochs, val_acc, 'c', label='Validation acc')
# # plt.title('Training and validation accuracy')
# # plt.xlabel('Epochs')
# # plt.ylabel('Accuracy')
# # plt.legend()
# # plt.show()

# %%
from keras.callbacks import EarlyStopping
#set early stopping monitor so the model stops training when it won't improve anymore
early_stopping_monitor = EarlyStopping(patience=500)

#train model
history=model.fit(xTrain11, yTrain11, validation_data = (xTest11, yTest11), epochs=200, batch_size=16)
# Out:
# Epoch 1/150
# 22/22 [==============================] - 31s 36ms/step - loss: 0.6927 - accuracy: 0.5983 - val_loss: 0.6936 - val_accuracy: 0.4899
# Epoch 2/150
# 22/22 [==============================] - 0s 14ms/step - loss: 0.6199 - accuracy: 0.6734 - val_loss: 0.6958 - val_accuracy: 0.4899
# Epoch 3/150
# 22/22 [==============================] - 0s 14ms/step - loss: 0.6087 - accuracy: 0.6965 - val_loss: 0.7018 - val_accuracy: 0.4899
# Epoch 4/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.5916 - accuracy: 0.6734 - val_loss: 0.7054 - val_accuracy: 0.4899
# Epoch 5/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.5797 - accuracy: 0.7052 - val_loss: 0.7083 - val_accuracy: 0.4899
# Epoch 6/150
# 22/22 [==============================] - 0s 14ms/step - loss: 0.5510 - accuracy: 0.6908 - val_loss: 0.7203 - val_accuracy: 0.4899
# Epoch 7/150
# 22/22 [==============================] - 0s 14ms/step - loss: 0.6021 - accuracy: 0.6908 - val_loss: 0.7256 - val_accuracy: 0.4899
# Epoch 8/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.5664 - accuracy: 0.7052 - val_loss: 0.7336 - val_accuracy: 0.4899
# Epoch 9/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.5454 - accuracy: 0.7370 - val_loss: 0.7335 - val_accuracy: 0.4899
# Epoch 10/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.5818 - accuracy: 0.6763 - val_loss: 0.7346 - val_accuracy: 0.4899
# Epoch 11/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.5406 - accuracy: 0.7197 - val_loss: 0.7305 - val_accuracy: 0.4899
# Epoch 12/150
# 22/22 [==============================] - 0s 14ms/step - loss: 0.4824 - accuracy: 0.7572 - val_loss: 0.7617 - val_accuracy: 0.4899
# Epoch 13/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.5464 - accuracy: 0.7081 - val_loss: 0.8041 - val_accuracy: 0.4899
# Epoch 14/150
# 22/22 [==============================] - 0s 12ms/step - loss: 0.5584 - accuracy: 0.7052 - val_loss: 0.8261 - val_accuracy: 0.4899
# Epoch 15/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.5219 - accuracy: 0.7283 - val_loss: 0.8656 - val_accuracy: 0.4899
# Epoch 16/150
# 22/22 [==============================] - 0s 14ms/step - loss: 0.4649 - accuracy: 0.7688 - val_loss: 0.8152 - val_accuracy: 0.4899
# Epoch 17/150
# 22/22 [==============================] - 0s 14ms/step - loss: 0.4370 - accuracy: 0.8150 - val_loss: 0.8243 - val_accuracy: 0.4899
# Epoch 18/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.4626 - accuracy: 0.7948 - val_loss: 0.8362 - val_accuracy: 0.4899
# Epoch 19/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.4070 - accuracy: 0.8179 - val_loss: 1.0226 - val_accuracy: 0.4899
# Epoch 20/150
# 22/22 [==============================] - 0s 14ms/step - loss: 0.3475 - accuracy: 0.8555 - val_loss: 1.1998 - val_accuracy: 0.4899
# Epoch 21/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.3385 - accuracy: 0.8555 - val_loss: 1.3259 - val_accuracy: 0.4899
# Epoch 22/150
# 22/22 [==============================] - 0s 14ms/step - loss: 0.3068 - accuracy: 0.8613 - val_loss: 0.8560 - val_accuracy: 0.6174
# Epoch 23/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.3521 - accuracy: 0.8497 - val_loss: 0.9649 - val_accuracy: 0.5034
# Epoch 24/150
# 22/22 [==============================] - 0s 14ms/step - loss: 0.3652 - accuracy: 0.8208 - val_loss: 0.6687 - val_accuracy: 0.6913
# Epoch 25/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.3245 - accuracy: 0.8699 - val_loss: 0.6396 - val_accuracy: 0.6779
# Epoch 26/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.2813 - accuracy: 0.8757 - val_loss: 0.9353 - val_accuracy: 0.6376
# Epoch 27/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.2398 - accuracy: 0.9191 - val_loss: 0.6828 - val_accuracy: 0.6846
# Epoch 28/150
# 22/22 [==============================] - 0s 14ms/step - loss: 0.1933 - accuracy: 0.9191 - val_loss: 0.9590 - val_accuracy: 0.6644
# Epoch 29/150
# 22/22 [==============================] - 0s 14ms/step - loss: 0.1807 - accuracy: 0.9277 - val_loss: 0.7136 - val_accuracy: 0.6711
# Epoch 30/150
# 22/22 [==============================] - 0s 12ms/step - loss: 0.1598 - accuracy: 0.9364 - val_loss: 1.0700 - val_accuracy: 0.6510
# Epoch 31/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.1505 - accuracy: 0.9480 - val_loss: 0.7181 - val_accuracy: 0.6577
# Epoch 32/150
# 22/22 [==============================] - 0s 14ms/step - loss: 0.1166 - accuracy: 0.9653 - val_loss: 0.9481 - val_accuracy: 0.6242
# Epoch 33/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0750 - accuracy: 0.9711 - val_loss: 1.2596 - val_accuracy: 0.6644
# Epoch 34/150
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0855 - accuracy: 0.9624 - val_loss: 2.8715 - val_accuracy: 0.5839
# Epoch 35/150
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0869 - accuracy: 0.9769 - val_loss: 15.2230 - val_accuracy: 0.5101
# Epoch 36/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0568 - accuracy: 0.9855 - val_loss: 1.7792 - val_accuracy: 0.7047
# Epoch 37/150
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0601 - accuracy: 0.9855 - val_loss: 1.9763 - val_accuracy: 0.6376
# Epoch 38/150
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0434 - accuracy: 0.9884 - val_loss: 0.9635 - val_accuracy: 0.6980
# Epoch 39/150
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0748 - accuracy: 0.9624 - val_loss: 1.1249 - val_accuracy: 0.6040
# Epoch 40/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.1387 - accuracy: 0.9480 - val_loss: 3.4420 - val_accuracy: 0.5503
# Epoch 41/150
# 22/22 [==============================] - 0s 12ms/step - loss: 0.1801 - accuracy: 0.9220 - val_loss: 2.1857 - val_accuracy: 0.5973
# Epoch 42/150
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0907 - accuracy: 0.9711 - val_loss: 2.4647 - val_accuracy: 0.6510
# Epoch 43/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0404 - accuracy: 0.9884 - val_loss: 6.2447 - val_accuracy: 0.6040
# Epoch 44/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0699 - accuracy: 0.9740 - val_loss: 11.3471 - val_accuracy: 0.5369
# Epoch 45/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.2771 - accuracy: 0.8902 - val_loss: 5.2000 - val_accuracy: 0.5369
# Epoch 46/150
# 22/22 [==============================] - 0s 12ms/step - loss: 0.1538 - accuracy: 0.9220 - val_loss: 17.5965 - val_accuracy: 0.5101
# Epoch 47/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0621 - accuracy: 0.9740 - val_loss: 12.8573 - val_accuracy: 0.5101
# Epoch 48/150
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0602 - accuracy: 0.9855 - val_loss: 9.8877 - val_accuracy: 0.5101
# Epoch 49/150
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0351 - accuracy: 0.9913 - val_loss: 9.8195 - val_accuracy: 0.5101
# Epoch 50/150
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0248 - accuracy: 0.9884 - val_loss: 5.2506 - val_accuracy: 0.5638
# Epoch 51/150
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0133 - accuracy: 1.0000 - val_loss: 3.8204 - val_accuracy: 0.6711
# Epoch 52/150
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0216 - accuracy: 0.9942 - val_loss: 6.1094 - val_accuracy: 0.5503
# Epoch 53/150
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0173 - accuracy: 0.9942 - val_loss: 2.0318 - val_accuracy: 0.7181
# Epoch 54/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 1.7454 - val_accuracy: 0.7181
# Epoch 55/150
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0081 - accuracy: 0.9971 - val_loss: 1.8375 - val_accuracy: 0.7315
# Epoch 56/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0115 - accuracy: 0.9971 - val_loss: 2.3199 - val_accuracy: 0.6913
# Epoch 57/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0245 - accuracy: 0.9855 - val_loss: 4.4126 - val_accuracy: 0.6376
# Epoch 58/150
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0156 - accuracy: 0.9971 - val_loss: 1.9889 - val_accuracy: 0.6846
# Epoch 59/150
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0129 - accuracy: 0.9942 - val_loss: 1.8403 - val_accuracy: 0.7181
# Epoch 60/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0261 - accuracy: 0.9884 - val_loss: 2.1049 - val_accuracy: 0.7315
# Epoch 61/150
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0463 - accuracy: 0.9769 - val_loss: 1.9310 - val_accuracy: 0.6443
# Epoch 62/150
# 22/22 [==============================] - 0s 12ms/step - loss: 0.1322 - accuracy: 0.9538 - val_loss: 3.7267 - val_accuracy: 0.6510
# Epoch 63/150
# 22/22 [==============================] - 0s 12ms/step - loss: 0.2211 - accuracy: 0.9220 - val_loss: 9.1439 - val_accuracy: 0.5503
# Epoch 64/150
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0870 - accuracy: 0.9566 - val_loss: 24.1577 - val_accuracy: 0.5101
# Epoch 65/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0588 - accuracy: 0.9827 - val_loss: 15.7226 - val_accuracy: 0.5302
# Epoch 66/150
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0490 - accuracy: 0.9884 - val_loss: 10.2215 - val_accuracy: 0.6577
# Epoch 67/150
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0626 - accuracy: 0.9798 - val_loss: 10.7731 - val_accuracy: 0.6376
# Epoch 68/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0591 - accuracy: 0.9827 - val_loss: 2.0830 - val_accuracy: 0.6846
# Epoch 69/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0347 - accuracy: 0.9884 - val_loss: 1.9258 - val_accuracy: 0.6711
# Epoch 70/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0545 - accuracy: 0.9884 - val_loss: 1.0569 - val_accuracy: 0.6846
# Epoch 71/150
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0224 - accuracy: 0.9942 - val_loss: 1.0469 - val_accuracy: 0.6980
# Epoch 72/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 1.1299 - val_accuracy: 0.6846
# Epoch 73/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.9034 - val_accuracy: 0.7315
# Epoch 74/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.9203 - val_accuracy: 0.7383
# Epoch 75/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 1.0925 - val_accuracy: 0.7114
# Epoch 76/150
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 1.0483 - val_accuracy: 0.7315
# Epoch 77/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.0746 - val_accuracy: 0.7383
# Epoch 78/150
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0042 - accuracy: 0.9971 - val_loss: 1.2727 - val_accuracy: 0.7315
# Epoch 79/150
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0134 - accuracy: 0.9942 - val_loss: 4.5490 - val_accuracy: 0.6711
# Epoch 80/150
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0241 - accuracy: 0.9942 - val_loss: 4.8454 - val_accuracy: 0.6980
# Epoch 81/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0125 - accuracy: 0.9971 - val_loss: 1.6662 - val_accuracy: 0.7383
# Epoch 82/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0116 - accuracy: 1.0000 - val_loss: 2.1122 - val_accuracy: 0.7248
# Epoch 83/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0462 - accuracy: 0.9855 - val_loss: 4.9795 - val_accuracy: 0.6913
# Epoch 84/150
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0178 - accuracy: 0.9942 - val_loss: 3.4321 - val_accuracy: 0.6846
# Epoch 85/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0164 - accuracy: 0.9942 - val_loss: 3.7008 - val_accuracy: 0.6577
# Epoch 86/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0237 - accuracy: 0.9913 - val_loss: 4.7323 - val_accuracy: 0.6644
# Epoch 87/150
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0136 - accuracy: 0.9971 - val_loss: 3.9011 - val_accuracy: 0.7047
# Epoch 88/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0061 - accuracy: 0.9971 - val_loss: 3.7680 - val_accuracy: 0.7114
# Epoch 89/150
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 2.4591 - val_accuracy: 0.7047
# Epoch 90/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 2.5673 - val_accuracy: 0.6846
# Epoch 91/150
# 22/22 [==============================] - 0s 14ms/step - loss: 9.5279e-04 - accuracy: 1.0000 - val_loss: 2.2584 - val_accuracy: 0.6779
# Epoch 92/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 2.2716 - val_accuracy: 0.6846
# Epoch 93/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 2.1900 - val_accuracy: 0.6980
# Epoch 94/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.9676 - val_accuracy: 0.7383
# Epoch 95/150
# 22/22 [==============================] - 0s 14ms/step - loss: 4.0595e-04 - accuracy: 1.0000 - val_loss: 1.8940 - val_accuracy: 0.7248
# Epoch 96/150
# 22/22 [==============================] - 0s 12ms/step - loss: 5.3049e-04 - accuracy: 1.0000 - val_loss: 1.8330 - val_accuracy: 0.7248
# Epoch 97/150
# 22/22 [==============================] - 0s 14ms/step - loss: 4.6119e-04 - accuracy: 1.0000 - val_loss: 1.8813 - val_accuracy: 0.7248
# Epoch 98/150
# 22/22 [==============================] - 0s 12ms/step - loss: 3.3817e-04 - accuracy: 1.0000 - val_loss: 1.8698 - val_accuracy: 0.7114
# Epoch 99/150
# 22/22 [==============================] - 0s 14ms/step - loss: 3.2646e-04 - accuracy: 1.0000 - val_loss: 1.7796 - val_accuracy: 0.6980
# Epoch 100/150
# 22/22 [==============================] - 0s 14ms/step - loss: 3.3711e-04 - accuracy: 1.0000 - val_loss: 1.7861 - val_accuracy: 0.7047
# Epoch 101/150
# 22/22 [==============================] - 0s 13ms/step - loss: 5.3895e-04 - accuracy: 1.0000 - val_loss: 1.8799 - val_accuracy: 0.7383
# Epoch 102/150
# 22/22 [==============================] - 0s 14ms/step - loss: 1.8558e-04 - accuracy: 1.0000 - val_loss: 1.8786 - val_accuracy: 0.7248
# Epoch 103/150
# 22/22 [==============================] - 0s 12ms/step - loss: 4.2248e-04 - accuracy: 1.0000 - val_loss: 1.7943 - val_accuracy: 0.7114
# Epoch 104/150
# 22/22 [==============================] - 0s 13ms/step - loss: 3.3427e-04 - accuracy: 1.0000 - val_loss: 1.8022 - val_accuracy: 0.7181
# Epoch 105/150
# 22/22 [==============================] - 0s 14ms/step - loss: 3.8684e-04 - accuracy: 1.0000 - val_loss: 1.8121 - val_accuracy: 0.7114
# Epoch 106/150
# 22/22 [==============================] - 0s 13ms/step - loss: 8.4054e-04 - accuracy: 1.0000 - val_loss: 1.7285 - val_accuracy: 0.7248
# Epoch 107/150
# 22/22 [==============================] - 0s 13ms/step - loss: 3.9671e-04 - accuracy: 1.0000 - val_loss: 1.6278 - val_accuracy: 0.7383
# Epoch 108/150
# 22/22 [==============================] - 0s 13ms/step - loss: 4.8171e-04 - accuracy: 1.0000 - val_loss: 1.6677 - val_accuracy: 0.7450
# Epoch 109/150
# 22/22 [==============================] - 0s 14ms/step - loss: 4.4328e-04 - accuracy: 1.0000 - val_loss: 1.7398 - val_accuracy: 0.7315
# Epoch 110/150
# 22/22 [==============================] - 0s 13ms/step - loss: 2.8260e-04 - accuracy: 1.0000 - val_loss: 1.8393 - val_accuracy: 0.7114
# Epoch 111/150
# 22/22 [==============================] - 0s 14ms/step - loss: 3.0029e-04 - accuracy: 1.0000 - val_loss: 1.7977 - val_accuracy: 0.7383
# Epoch 112/150
# 22/22 [==============================] - 0s 13ms/step - loss: 2.0258e-04 - accuracy: 1.0000 - val_loss: 1.7912 - val_accuracy: 0.7383
# Epoch 113/150
# 22/22 [==============================] - 0s 14ms/step - loss: 4.7047e-04 - accuracy: 1.0000 - val_loss: 1.8742 - val_accuracy: 0.7248
# Epoch 114/150
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0051 - accuracy: 0.9971 - val_loss: 5.2983 - val_accuracy: 0.6309
# Epoch 115/150
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0190 - accuracy: 0.9942 - val_loss: 2.2074 - val_accuracy: 0.6577
# Epoch 116/150
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0346 - accuracy: 0.9942 - val_loss: 2.8669 - val_accuracy: 0.6846
# Epoch 117/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0356 - accuracy: 0.9913 - val_loss: 6.8483 - val_accuracy: 0.5973
# Epoch 118/150
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0393 - accuracy: 0.9855 - val_loss: 2.9284 - val_accuracy: 0.5638
# Epoch 119/150
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0647 - accuracy: 0.9769 - val_loss: 0.9793 - val_accuracy: 0.7114
# Epoch 120/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0365 - accuracy: 0.9855 - val_loss: 71.7347 - val_accuracy: 0.5101
# Epoch 121/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.1301 - accuracy: 0.9480 - val_loss: 46.2392 - val_accuracy: 0.5168
# Epoch 122/150
# 22/22 [==============================] - 0s 12ms/step - loss: 0.2921 - accuracy: 0.9335 - val_loss: 6.4734 - val_accuracy: 0.5839
# Epoch 123/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.1406 - accuracy: 0.9422 - val_loss: 3.3240 - val_accuracy: 0.6443
# Epoch 124/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0197 - accuracy: 0.9971 - val_loss: 3.8402 - val_accuracy: 0.6174
# Epoch 125/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 4.6861 - val_accuracy: 0.6309
# Epoch 126/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 3.7566 - val_accuracy: 0.6443
# Epoch 127/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 3.3926 - val_accuracy: 0.6644
# Epoch 128/150
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 2.6049 - val_accuracy: 0.6846
# Epoch 129/150
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0111 - accuracy: 0.9971 - val_loss: 2.1049 - val_accuracy: 0.7181
# Epoch 130/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 1.9702 - val_accuracy: 0.7248
# Epoch 131/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 2.0688 - val_accuracy: 0.6980
# Epoch 132/150
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 2.6006 - val_accuracy: 0.7315
# Epoch 133/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 2.5975 - val_accuracy: 0.7248
# Epoch 134/150
# 22/22 [==============================] - 0s 14ms/step - loss: 5.8794e-04 - accuracy: 1.0000 - val_loss: 2.4289 - val_accuracy: 0.7114
# Epoch 135/150
# 22/22 [==============================] - 0s 14ms/step - loss: 4.8586e-04 - accuracy: 1.0000 - val_loss: 2.2547 - val_accuracy: 0.7047
# Epoch 136/150
# 22/22 [==============================] - 0s 12ms/step - loss: 9.2676e-04 - accuracy: 1.0000 - val_loss: 2.0835 - val_accuracy: 0.7114
# Epoch 137/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 2.0919 - val_accuracy: 0.7248
# Epoch 138/150
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.9984 - val_accuracy: 0.7248
# Epoch 139/150
# 22/22 [==============================] - 0s 13ms/step - loss: 7.3920e-04 - accuracy: 1.0000 - val_loss: 1.5991 - val_accuracy: 0.7450
# Epoch 140/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0053 - accuracy: 0.9971 - val_loss: 2.3755 - val_accuracy: 0.7181
# Epoch 141/150
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 2.1441 - val_accuracy: 0.7248
# Epoch 142/150
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.4769 - val_accuracy: 0.7383
# Epoch 143/150
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 1.4492 - val_accuracy: 0.7315
# Epoch 144/150
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.5366 - val_accuracy: 0.7383
# Epoch 145/150
# 22/22 [==============================] - 0s 13ms/step - loss: 4.0940e-04 - accuracy: 1.0000 - val_loss: 1.4008 - val_accuracy: 0.7315
# Epoch 146/150
# 22/22 [==============================] - 0s 12ms/step - loss: 9.1717e-04 - accuracy: 1.0000 - val_loss: 1.4155 - val_accuracy: 0.7450
# Epoch 147/150
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0064 - accuracy: 0.9971 - val_loss: 2.0225 - val_accuracy: 0.7047
# Epoch 148/150
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0032 - accuracy: 0.9971 - val_loss: 3.5183 - val_accuracy: 0.6779
# Epoch 149/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 1.7760 - val_accuracy: 0.7047
# Epoch 150/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 1.8206 - val_accuracy: 0.7047

# %%
import os
import seaborn as sns
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
prediction_NN = model.predict(xTest11)
prediction_NN = np.argmax(prediction_NN, axis=-1)
#Print overall accuracy
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(yTest1, prediction_NN))
#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(yTest1, prediction_NN)
print(cm)
sns.heatmap(cm, annot=True)
# Out:
# Accuracy =  0.7046979865771812
# [[45 28]
#  [16 60]]
