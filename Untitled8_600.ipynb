# %% [markdown]
# <a href="https://colab.research.google.com/github/rohitsubodh/GAN/blob/main/Untitled8_550.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import keras
import numpy as np
from keras import models
from keras import layers
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score
from sklearn.datasets import make_classification
from matplotlib import pyplot
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import preprocessing
from keras.models import Sequential,Model
from keras.layers import Dense, Dropout,Input, Conv1D, MaxPooling1D, UpSampling1D, concatenate, BatchNormalization, Activation, add
from keras.layers import Embedding,LeakyReLU
from keras.layers import Conv1D, GlobalAveragePooling1D, MaxPooling1D, Flatten, LocallyConnected1D, BatchNormalization
import scipy.signal
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.decomposition import PCA, KernelPCA

# %%
data = pd.read_excel('/content/PPG_new.xlsx',sheet_name='0-1')
target = pd.read_excel('/content/PPG_new.xlsx',sheet_name='target 0-1')

# %%
# data1=data
# kpca=KernelPCA(kernel="rbf",fit_inverse_transform=True, gamma=10)
# data=kpca.fit_transform(data)

# %%
# data1=data
# kpca=KernelPCA(kernel="rbf",fit_inverse_transform=True, gamma=10)
# data=kpca.fit_transform(data)
# data.shape

# %%
# x= data[0,:]
x=data.iloc[0,:]
plt.plot(x)
plt.show
data1=data

# %%
# from sklearn.preprocessing import StandardScaler,MinMaxScaler

# data = StandardScaler().fit_transform(data)
# data=MinMaxScaler().fit_transform(data)

# %%
# Applying median filter
data=scipy.signal.medfilt(data)
data
x= data[0,:]
plt.plot(x)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
# Design of low pass chebyshev filter
sos= scipy.signal.cheby2(4, 10, 25, 'low', fs=1000, output='sos')
sos
# Out:
# array([[ 0.26741176, -0.49141861,  0.26741176,  1.        , -1.6346899 ,
#          0.69069827],
#        [ 1.        , -1.97118242,  1.        ,  1.        , -1.92658177,
#          0.94891457]])

# %%
data= scipy.signal.sosfilt(sos, data) # applying chebyshev filter
x= data[0,:]
plt.plot(x)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
# Applying backward forward filter
b, a = scipy.signal.butter(8, 0.125) # filter design

data = scipy.signal.filtfilt(b, a, data, method="gust")

x= data[0,:]
plt.plot(x)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
data1=data
kpca=KernelPCA(kernel="rbf",fit_inverse_transform=True, gamma=10)
data=kpca.fit_transform(data)
data.shape
# Out:
# (495, 494)

# %%
x= data[0,:]
plt.plot(x)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
# from sklearn.preprocessing import StandardScaler

# data = StandardScaler().fit_transform(data)

# xTrain1 = scaler.transform(xTrain1)

# xTest1 = scaler.transform(xTest1)

# %%
from sklearn.model_selection import train_test_split
xTrain1, xTest1, yTrain1, yTest1 = train_test_split(data, target, test_size = 0.3, random_state = 42)

# %%
# from sklearn.preprocessing import StandardScaler

# scaler = StandardScaler().fit(xTrain1)

# xTrain1 = scaler.transform(xTrain1)

# xTest1 = scaler.transform(xTest1)

# %%
xTrain11 = np.expand_dims(xTrain1, axis=2)
yTrain11 = tf.keras.utils.to_categorical(yTrain1, num_classes=2)
xTest11 =  np.expand_dims(xTest1, axis=2)
yTest11 = tf.keras.utils.to_categorical(yTest1, num_classes=2)

# %%
# input_shape = (2100, 1)
input_shape = (494, 1)

# %%
  #   x = 64
  # #  from keras
  #   inputs = Input(input_shape)
  #   conv1 = Conv1D(x,3, activation='relu', padding='same')(inputs)
  #   conv1 = BatchNormalization()(conv1)
  #   conv1 = Conv1D(x,3, activation='relu', padding='same')(conv1)
  #   conv1 = BatchNormalization()(conv1)
  #   pool1 = MaxPooling1D(pool_size=2)(conv1)

  #   conv2 = Conv1D(x*2,3, activation='relu', padding='same')(pool1)
  #   conv2 = BatchNormalization()(conv2)
  #   conv2 = Conv1D(x*2,3, activation='relu', padding='same')(conv2)
  #   conv2 = BatchNormalization()(conv2)
  #   pool2 = MaxPooling1D(pool_size=2)(conv2)

  #   conv3 = Conv1D(x*4,3, activation='relu', padding='same')(pool2)
  #   conv3 = BatchNormalization()(conv3)
  #   conv3 = Conv1D(x*4,3, activation='relu', padding='same')(conv3)
  #   conv3 = BatchNormalization()(conv3)
  #   pool3 = MaxPooling1D(pool_size=2)(conv3)

  #   conv4 = Conv1D(x*8,3, activation='relu', padding='same')(pool3)
  #   conv4 = BatchNormalization()(conv4)
  #   conv4 = Conv1D(x*8,3, activation='relu', padding='same')(conv4)
  #   conv4 = BatchNormalization()(conv4)
  #   pool4 = MaxPooling1D(pool_size=2)(conv4)

  #   conv5 = Conv1D(x*16, 3, activation='relu', padding='same')(pool4)
  #   conv5 = BatchNormalization()(conv5)
  #   conv5 = Conv1D(x*16, 3, activation='relu', padding='same')(conv5)
  #   conv5 = BatchNormalization()(conv5)

  #   up6 = concatenate([UpSampling1D(size=2)(conv5), conv4], axis=2)
  #   conv6 = Conv1D(x*8, 3, activation='relu', padding='same')(up6)
  #   conv6 = BatchNormalization()(conv6)
  #   conv6 = Conv1D(x*8, 3, activation='relu', padding='same')(conv6)
  #   conv6 = BatchNormalization()(conv6)
    
  #   up7 = concatenate([UpSampling1D(size=2)(conv6), conv3], axis=2)
  #   conv7 = Conv1D(x*4, 3, activation='relu', padding='same')(up7)
  #   conv7 = BatchNormalization()(conv7)
  #   conv7 = Conv1D(x*4, 3, activation='relu', padding='same')(conv7)
  #   conv7 = BatchNormalization()(conv7)

  #   up8 = concatenate([UpSampling1D(size=2)(conv7), conv2], axis=2)
  #   conv8 = Conv1D(x*2, 3, activation='relu', padding='same')(up8)
  #   conv8 = BatchNormalization()(conv8)
  #   conv8 = Conv1D(x*2, 3, activation='relu', padding='same')(conv8)
  #   conv8 = BatchNormalization()(conv8)

  #   up9 = concatenate([UpSampling1D(size=2)(conv8), conv1], axis=2)
  #   conv9 = Conv1D(x, 3, activation='relu', padding='same')(up9)
  #   conv9 = BatchNormalization()(conv9)
  #   conv9 = Conv1D(x, 3, activation='relu', padding='same')(conv9)
  #   conv9 = BatchNormalization()(conv9)

  #   conv10 = Conv1D(1, 1)(conv9)

  #   model = Model(inputs=[inputs], outputs=[conv10])
  #   # model.compile(loss='mean_absolute_error',optimizer='adam',metrics=['mean_squared_error'], loss_weights=[1., 0.9, 0.8, 0.7, 0.6])                                                         
  #   model.compile(loss='categorical_crossentropy',
  #                   optimizer='adam',
  #                   metrics=['accuracy'])

  #   # checkpoint1_ = ModelCheckpoint(os.path.join('models','{}_model1_fold{}.h5'.format(mdlName1,foldname)), verbose=1, monitor='val_out_loss',save_best_only=True, mode='auto')  
  #                                                                       # train approximation network for 100 epochs
  #   # history1 = mdl1.fit(X_train,{'out': Y_train['out'], 'level1': Y_train['level1'], 'level2':Y_train['level2'], 'level3':Y_train['level3'] , 'level4':Y_train['level4']},epochs=100,batch_size=256,validation_data=(X_val,{'out': Y_val['out'], 'level1': Y_val['level1'], 'level2':Y_val['level2'], 'level3':Y_val['level3'] , 'level4':Y_val['level4']}),callbacks=[checkpoint1_],verbose=1)
  #   history = model.fit(xTrain1, yTrain1, validation_split=0.3, epochs=200, batch_size=20, verbose=2)

# %%
#CNN Model

model = Sequential()
model.add(Conv1D(32, 3, activation='relu', input_shape=input_shape[0:]))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.1))
model.add(Conv1D(64, 3, activation='relu', name="my_intermediate_layer"))
model.add(MaxPooling1D(3))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.1))
model.add(Conv1D(128, 3, activation='relu'))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.1))
model.add(Conv1D(256, 3, activation='relu'))
model.add(GlobalAveragePooling1D())
model.add(Dropout(0.5))
model.add(Dense(100, name="dense"))
model.add(Dense(2, activation='softmax', name="dense1"))
model.compile(loss='categorical_crossentropy',
                    optimizer='adam',
                    metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 492, 32)           128
# _________________________________________________________________
# batch_normalization (BatchNo (None, 492, 32)           128
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 492, 32)           0
# _________________________________________________________________
# my_intermediate_layer (Conv1 (None, 490, 64)           6208
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 163, 64)           0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 163, 64)           256
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 163, 64)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 161, 128)          24704
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 161, 128)          512
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 161, 128)          0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 159, 256)          98560
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 256)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 100)               25700
# _________________________________________________________________
# dense1 (Dense)               (None, 2)                 202
# =================================================================
# Total params: 156,398
# Trainable params: 155,950
# Non-trainable params: 448
# _________________________________________________________________

# %%
# from sklearn.model_selection import train_test_split
# xTrain1, xTest1, yTrain1, yTest1 = train_test_split(data, target, test_size = 0.3, random_state = 42)

# xTrain1.shape, yTest1.shape

# xTrain11 = np.expand_dims(xTrain1, axis=2)
# yTrain11 = tf.keras.utils.to_categorical(yTrain1, num_classes=2)
# xTest11 =  np.expand_dims(xTest1, axis=2)
# yTest11 = tf.keras.utils.to_categorical(yTest1, num_classes=2)

# input_shape = (2100, 1)

# model = Sequential()

# model.add(Dense(128, activation='relu', input_shape=(2100, ) ))
# #model.add(Dropout(0.2))
# model.add(BatchNormalization())

# model.add(Dense(64, activation='relu', kernel_regularizer='l2', kernel_initializer='he_uniform'))
# model.add(BatchNormalization())
# model.add(Dropout(0.5))
# model.add(Dense(32, activation='relu', kernel_regularizer='l2', kernel_initializer='he_uniform'))
# model.add(BatchNormalization())
# model.add(Dropout(0.1))
# model.add(Dense(16, activation='relu', kernel_regularizer='l2', kernel_initializer='he_uniform'))
# model.add(BatchNormalization())
# model.add(Dropout(0.1))
# #model.add(Dense(16, activation='relu', kernel_regularizer='l2'))
# #model.add(Dropout(0.05))
# #model.add(Dense(64, activation='relu'))#

# model.add(Dense(1, activation='sigmoid')) 
# opt = tf.keras.optimizers.Adam(learning_rate=.005)
# model.compile(loss='binary_crossentropy',
#               optimizer= opt,
#                metrics=['accuracy'])
# model.summary()               
# history = model.fit(xTrain1, yTrain1, validation_split=0.3, epochs=200, batch_size=20, verbose=2)

# # model.evaluate(x=xTest1, y=yTest1, verbose=2)

# # import os
# # import seaborn as sns
# # #plot the training and validation accuracy and loss at each epoch
# # loss = history.history['loss']
# # val_loss = history.history['val_loss']
# # epochs = range(1, len(loss) + 1)
# # plt.plot(loss[10:], 'b', label='Training loss')
# # plt.plot(val_loss[10:], 'g', label='Validation loss')
# # plt.title('Training and validation loss')
# # plt.xlabel('Epochs')
# # plt.ylabel('Loss')
# # plt.legend()
# # plt.show()

# # acc = history.history['accuracy']
# # val_acc = history.history['val_accuracy']
# # plt.plot(epochs, acc, 'r', label='Training acc')
# # plt.plot(epochs, val_acc, 'c', label='Validation acc')
# # plt.title('Training and validation accuracy')
# # plt.xlabel('Epochs')
# # plt.ylabel('Accuracy')
# # plt.legend()
# # plt.show()

# %%
from keras.callbacks import EarlyStopping
#set early stopping monitor so the model stops training when it won't improve anymore
early_stopping_monitor = EarlyStopping(patience=500)

#train model
history=model.fit(xTrain11, yTrain11, validation_data = (xTest11, yTest11), epochs=250, batch_size=16)
# Out:
# Epoch 1/250
# 22/22 [==============================] - 0s 17ms/step - loss: 1.1267e-04 - accuracy: 1.0000 - val_loss: 2.9637 - val_accuracy: 0.7248
# Epoch 2/250
# 22/22 [==============================] - 0s 16ms/step - loss: 2.0192e-04 - accuracy: 1.0000 - val_loss: 2.9081 - val_accuracy: 0.7315
# Epoch 3/250
# 22/22 [==============================] - 0s 16ms/step - loss: 3.2008e-04 - accuracy: 1.0000 - val_loss: 2.7998 - val_accuracy: 0.7248
# Epoch 4/250
# 22/22 [==============================] - 0s 14ms/step - loss: 9.1958e-05 - accuracy: 1.0000 - val_loss: 2.8199 - val_accuracy: 0.7315
# Epoch 5/250
# 22/22 [==============================] - 0s 14ms/step - loss: 1.8780e-05 - accuracy: 1.0000 - val_loss: 2.8706 - val_accuracy: 0.7315
# Epoch 6/250
# 22/22 [==============================] - 0s 15ms/step - loss: 2.4908e-05 - accuracy: 1.0000 - val_loss: 2.9145 - val_accuracy: 0.7315
# Epoch 7/250
# 22/22 [==============================] - 0s 14ms/step - loss: 1.2340e-04 - accuracy: 1.0000 - val_loss: 2.9573 - val_accuracy: 0.7248
# Epoch 8/250
# 22/22 [==============================] - 0s 14ms/step - loss: 6.0731e-05 - accuracy: 1.0000 - val_loss: 2.9965 - val_accuracy: 0.7315
# Epoch 9/250
# 22/22 [==============================] - 0s 14ms/step - loss: 3.6940e-05 - accuracy: 1.0000 - val_loss: 3.0111 - val_accuracy: 0.7248
# Epoch 10/250
# 22/22 [==============================] - 0s 15ms/step - loss: 6.4498e-05 - accuracy: 1.0000 - val_loss: 3.0068 - val_accuracy: 0.7248
# Epoch 11/250
# 22/22 [==============================] - 0s 15ms/step - loss: 2.5470e-05 - accuracy: 1.0000 - val_loss: 3.0317 - val_accuracy: 0.7248
# Epoch 12/250
# 22/22 [==============================] - 0s 14ms/step - loss: 3.0559e-05 - accuracy: 1.0000 - val_loss: 3.0441 - val_accuracy: 0.7248
# Epoch 13/250
# 22/22 [==============================] - 0s 14ms/step - loss: 2.5919e-05 - accuracy: 1.0000 - val_loss: 3.0597 - val_accuracy: 0.7181
# Epoch 14/250
# 22/22 [==============================] - 0s 15ms/step - loss: 1.9152e-05 - accuracy: 1.0000 - val_loss: 3.0780 - val_accuracy: 0.7248
# Epoch 15/250
# 22/22 [==============================] - 0s 14ms/step - loss: 1.9415e-05 - accuracy: 1.0000 - val_loss: 3.0757 - val_accuracy: 0.7315
# Epoch 16/250
# 22/22 [==============================] - 0s 15ms/step - loss: 4.3724e-05 - accuracy: 1.0000 - val_loss: 3.1193 - val_accuracy: 0.7315
# Epoch 17/250
# 22/22 [==============================] - 0s 13ms/step - loss: 7.3392e-06 - accuracy: 1.0000 - val_loss: 3.1622 - val_accuracy: 0.7248
# Epoch 18/250
# 22/22 [==============================] - 0s 13ms/step - loss: 6.8837e-05 - accuracy: 1.0000 - val_loss: 3.2339 - val_accuracy: 0.7248
# Epoch 19/250
# 22/22 [==============================] - 0s 13ms/step - loss: 1.1089e-04 - accuracy: 1.0000 - val_loss: 3.2498 - val_accuracy: 0.7248
# Epoch 20/250
# 22/22 [==============================] - 0s 14ms/step - loss: 3.8777e-05 - accuracy: 1.0000 - val_loss: 3.2244 - val_accuracy: 0.7315
# Epoch 21/250
# 22/22 [==============================] - 0s 14ms/step - loss: 2.8271e-05 - accuracy: 1.0000 - val_loss: 3.2068 - val_accuracy: 0.7315
# Epoch 22/250
# 22/22 [==============================] - 0s 13ms/step - loss: 6.7589e-06 - accuracy: 1.0000 - val_loss: 3.1953 - val_accuracy: 0.7315
# Epoch 23/250
# 22/22 [==============================] - 0s 14ms/step - loss: 1
250
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 4.2973 - val_accuracy: 0.6779
# Epoch 105/250
# 22/22 [==============================] - 0s 13ms/step - loss: 7.0300e-04 - accuracy: 1.0000 - val_loss: 4.2660 - val_accuracy: 0.6577
# Epoch 106/250
# 22/22 [==============================] - 0s 14ms/step - loss: 9.2278e-04 - accuracy: 1.0000 - val_loss: 3.5185 - val_accuracy: 0.7181
# Epoch 107/250
# 22/22 [==============================] - 0s 14ms/step - loss: 4.6227e-04 - accuracy: 1.0000 - val_loss: 3.1985 - val_accuracy: 0.7114
# Epoch 108/250
# 22/22 [==============================] - 0s 15ms/step - loss: 3.0070e-04 - accuracy: 1.0000 - val_loss: 3.0641 - val_accuracy: 0.7181
# Epoch 109/250
# 22/22 [==============================] - 0s 13ms/step - loss: 3.9656e-04 - accuracy: 1.0000 - val_loss: 2.9949 - val_accuracy: 0.7181
# Epoch 110/250
# 22/22 [==============================] - 0s 14ms/step - loss: 2.5169e-04 - accuracy: 1.0000 - val_loss: 2.9604 - val_accuracy: 0.7248
# Epoch 111/250
# 22/22 [==============================] - 0s 14ms/step - loss: 1.7951e-04 - accuracy: 1.0000 - val_loss: 2.9264 - val_accuracy: 0.7315
# Epoch 112/250
# 22/22 [==============================] - 0s 15ms/step - loss: 2.5703e-04 - accuracy: 1.0000 - val_loss: 2.8761 - val_accuracy: 0.7450
# Epoch 113/250
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 2.7365 - val_accuracy: 0.7248
# Epoch 114/250
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0121 - accuracy: 0.9942 - val_loss: 4.0583 - val_accuracy: 0.6846
# Epoch 115/250
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0237 - accuracy: 0.9884 - val_loss: 16.1693 - val_accuracy: 0.5369
# Epoch 116/250
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0137 - accuracy: 0.9913 - val_loss: 6.0446 - val_accuracy: 0.6510
# Epoch 117/250
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 10.8197 - val_accuracy: 0.5302
# Epoch 118/250
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0174 - accuracy: 0.9942 - val_loss: 3.0502 - val_accuracy: 0.6577
# Epoch 119/250
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0121 - accuracy: 0.9971 - val_loss: 3.5113 - val_accuracy: 0.6309
# Epoch 120/250
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0117 - accuracy: 0.9971 - val_loss: 2.2717 - val_accuracy: 0.7181
# Epoch 121/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0051 - accuracy: 0.9971 - val_loss: 2.0618 - val_accuracy: 0.7248
# Epoch 122/250
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0055 - accuracy: 0.9971 - val_loss: 3.7303 - val_accuracy: 0.6913
# Epoch 123/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0102 - accuracy: 0.9971 - val_loss: 2.6355 - val_accuracy: 0.7315
# Epoch 124/250
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 2.1585 - val_accuracy: 0.7047
# Epoch 125/250
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0221 - accuracy: 0.9971 - val_loss: 2.0386 - val_accuracy: 0.6846
# Epoch 126/250
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0175 - accuracy: 0.9942 - val_loss: 6.1389 - val_accuracy: 0.5101
# Epoch 127/250
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 8.9521 - val_accuracy: 0.4899
# Epoch 128/250
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0090 - accuracy: 0.9971 - val_loss: 10.4860 - val_accuracy: 0.5168
# Epoch 129/250
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 17.1961 - val_accuracy: 0.5101
# Epoch 130/250
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 5.6163 - val_accuracy: 0.5772
# Epoch 131/250
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0041 - accuracy: 0.9971 - val_loss: 4.8462 - val_accuracy: 0.6040
# Epoch 132/250
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0073 - accuracy: 0.9971 - val_loss: 3.9154 - val_accuracy: 0.7047
# Epoch 133/250
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0164 - accuracy: 0.9913 - val_loss: 1.9975 - val_accuracy: 0.7181
# Epoch 134/250
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0158 - accuracy: 0.9913 - val_loss: 2.0722 - val_accuracy: 0.7047
# Epoch 135/250
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 2.6155 - val_accuracy: 0.7248
# Epoch 136/250
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0089 - accuracy: 0.9971 - val_loss: 2.9705 - val_accuracy: 0.6779
# Epoch 137/250
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 2.8206 - val_accuracy: 0.7181
# Epoch 138/250
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 2.8459 - val_accuracy: 0.6779
# Epoch 139/250
# 22/22 [==============================] - 0s 14ms/step - loss: 2
250
# 22/22 [==============================] - 0s 15ms/step - loss: 1.9448e-04 - accuracy: 1.0000 - val_loss: 2.9352 - val_accuracy: 0.7047
# Epoch 201/250
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 2.8352 - val_accuracy: 0.7047
# Epoch 202/250
# 22/22 [==============================] - 0s 15ms/step - loss: 1.4310e-04 - accuracy: 1.0000 - val_loss: 2.8909 - val_accuracy: 0.7047
# Epoch 203/250
# 22/22 [==============================] - 0s 14ms/step - loss: 8.4627e-05 - accuracy: 1.0000 - val_loss: 2.9869 - val_accuracy: 0.7114
# Epoch 204/250
# 22/22 [==============================] - 0s 16ms/step - loss: 2.1964e-04 - accuracy: 1.0000 - val_loss: 3.0846 - val_accuracy: 0.6980
# Epoch 205/250
# 22/22 [==============================] - 0s 15ms/step - loss: 2.3654e-04 - accuracy: 1.0000 - val_loss: 3.2400 - val_accuracy: 0.6779
# Epoch 206/250
# 22/22 [==============================] - 0s 15ms/step - loss: 1.0499e-04 - accuracy: 1.0000 - val_loss: 3.2877 - val_accuracy: 0.6779
# Epoch 207/250
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0034 - accuracy: 0.9971 - val_loss: 2.9079 - val_accuracy: 0.7047
# Epoch 208/250
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0086 - accuracy: 0.9971 - val_loss: 4.7059 - val_accuracy: 0.6779
# Epoch 209/250
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 5.1395 - val_accuracy: 0.6711
# Epoch 210/250
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 4.6407 - val_accuracy: 0.6779
# Epoch 211/250
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0066 - accuracy: 0.9971 - val_loss: 3.2107 - val_accuracy: 0.6846
# Epoch 212/250
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0170 - accuracy: 0.9971 - val_loss: 6.1305 - val_accuracy: 0.5839
# Epoch 213/250
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0108 - accuracy: 0.9971 - val_loss: 5.0445 - val_accuracy: 0.6980
# Epoch 214/250
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0213 - accuracy: 0.9971 - val_loss: 9.0567 - val_accuracy: 0.7047
# Epoch 215/250
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0264 - accuracy: 0.9913 - val_loss: 8.9584 - val_accuracy: 0.6711
# Epoch 216/250
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 8.8802 - val_accuracy: 0.5705
# Epoch 217/250
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0154 - accuracy: 0.9942 - val_loss: 5.9620 - val_accuracy: 0.6644
# Epoch 218/250
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0048 - accuracy: 0.9971 - val_loss: 5.8237 - val_accuracy: 0.6309
# Epoch 219/250
# 22/22 [==============================] - 0s 15ms/step - loss: 6.0349e-04 - accuracy: 1.0000 - val_loss: 5.3699 - val_accuracy: 0.6174
# Epoch 220/250
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0057 - accuracy: 0.9971 - val_loss: 7.2757 - val_accuracy: 0.5436
# Epoch 221/250
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0257 - accuracy: 0.9855 - val_loss: 5.0073 - val_accuracy: 0.6107
# Epoch 222/250
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0213 - accuracy: 0.9942 - val_loss: 11.4853 - val_accuracy: 0.5503
# Epoch 223/250
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0985 - accuracy: 0.9740 - val_loss: 1.5440 - val_accuracy: 0.6779
# Epoch 224/250
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0590 - accuracy: 0.9798 - val_loss: 1.4738 - val_accuracy: 0.6309
# Epoch 225/250
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0309 - accuracy: 0.9884 - val_loss: 1.7379 - val_accuracy: 0.6779
# Epoch 226/250
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 4.4260 - val_accuracy: 0.6107
# Epoch 227/250
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 4.9435 - val_accuracy: 0.6510
# Epoch 228/250
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 5.9114 - val_accuracy: 0.6376
# Epoch 229/250
# 22/22 [==============================] - 0s 15ms/step - loss: 9.8439e-04 - accuracy: 1.0000 - val_loss: 5.4185 - val_accuracy: 0.6376
# Epoch 230/250
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 4.5695 - val_accuracy: 0.6510
# Epoch 231/250
# 22/22 [==============================] - 0s 16ms/step - loss: 5.1526e-04 - accuracy: 1.0000 - val_loss: 4.1425 - val_accuracy: 0.6644
# Epoch 232/250
# 22/22 [==============================] - 0s 15ms/step - loss: 6.6090e-04 - accuracy: 1.0000 - val_loss: 3.5115 - val_accuracy: 0.6779
# Epoch 233/250
# 22/22 [==============================] - 0s 15ms/step - loss: 4.4677e-04 - accuracy: 1.0000 - val_loss: 3.2490 - val_accuracy: 0.6980
# Epoch 234/250
# 22/22 [==============================] - 0s 16ms/step - loss: 1.7796e-04 - accuracy: 1.0000 - val_loss: 3.1561 - val_accuracy: 0.6846
# Epoch 235/250
# 22/22 [==============================] - 0s 16ms/step - loss: 1.9709e-04 - accuracy: 1.0000 - val_loss: 3.1203 - val_accuracy: 0.6913
# Epoch 236/250
# 22/22 [==============================] - 0s 14ms/step - loss: 6.1501e-04 - accuracy: 1.0000 - val_loss: 3.1626 - val_accuracy: 0.6846
# Epoch 237/250
# 22/22 [==============================] - 0s 16ms/step - loss: 4.5859e-04 - accuracy: 1.0000 - val_loss: 3.1140 - val_accuracy: 0.6846
# Epoch 238/250
# 22/22 [==============================] - 0s 14ms/step - loss: 6.1950e-04 - accuracy: 1.0000 - val_loss: 3.0296 - val_accuracy: 0.6779
# Epoch 239/250
# 22/22 [==============================] - 0s 14ms/step - loss: 4.8337e-04 - accuracy: 1.0000 - val_loss: 3.0684 - val_accuracy: 0.7047
# Epoch 240/250
# 22/22 [==============================] - 0s 15ms/step - loss: 2.2744e-04 - accuracy: 1.0000 - val_loss: 3.0978 - val_accuracy: 0.6980
# Epoch 241/250
# 22/22 [==============================] - 0s 16ms/step - loss: 2.3630e-04 - accuracy: 1.0000 - val_loss: 3.1013 - val_accuracy: 0.6846
# Epoch 242/250
# 22/22 [==============================] - 0s 14ms/step - loss: 2.2581e-04 - accuracy: 1.0000 - val_loss: 3.1187 - val_accuracy: 0.6846
# Epoch 243/250
# 22/22 [==============================] - 0s 15ms/step - loss: 2.0930e-04 - accuracy: 1.0000 - val_loss: 3.1622 - val_accuracy: 0.6980
# Epoch 244/250
# 22/22 [==============================] - 0s 16ms/step - loss: 9.1255e-04 - accuracy: 1.0000 - val_loss: 3.9209 - val_accuracy: 0.6779
# Epoch 245/250
# 22/22 [==============================] - 0s 15ms/step - loss: 2.8737e-04 - accuracy: 1.0000 - val_loss: 4.7868 - val_accuracy: 0.6779
# Epoch 246/250
# 22/22 [==============================] - 0s 16ms/step - loss: 3.3543e-04 - accuracy: 1.0000 - val_loss: 4.3521 - val_accuracy: 0.6846
# Epoch 247/250
# 22/22 [==============================] - 0s 14ms/step - loss: 8.4457e-05 - accuracy: 1.0000 - val_loss: 4.1773 - val_accuracy: 0.6846
# Epoch 248/250
# 22/22 [==============================] - 0s 14ms/step - loss: 5.0246e-05 - accuracy: 1.0000 - val_loss: 4.1175 - val_accuracy: 0.6779
# Epoch 249/250
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 3.9817 - val_accuracy: 0.6846
# Epoch 250/250
# 22/22 [==============================] - 0s 15ms/step - loss: 3.7551e-04 - accuracy: 1.0000 - val_loss: 3.8705 - val_accuracy: 0.6980

# %%
import os
import seaborn as sns
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
prediction_NN = model.predict(xTest11)
prediction_NN = np.argmax(prediction_NN, axis=-1)
#Print overall accuracy
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(yTest1, prediction_NN))
#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(yTest1, prediction_NN)
print(cm)
sns.heatmap(cm, annot=True)
# Out:
# Accuracy =  0.697986577181208
# [[51 22]
#  [23 53]]
